# %% [markdown]
# # Datos de afiliación a la SS y Paro

# %% [markdown]
# En este cuaderno formateamos los datos de afiliación a la Seguridad Social y el paro, obtenidos a partir de hojas de cálculo presentes en las web de la SS y del SEPE, respectivamente.
#
# Pudimos haber separado estos datos uno en cada cuaderno, pero ya que su significado está muy relacionado, decidimos tratarlos conjuntamente. Por otro lado, tienen otro punto en común: se trata de datos distribuidos por municipios, no secciones electorales, que, de todas formas, pensamos que son útiles de todas formas.
#
# En el caso de los datos de la Seguridad Social, decidimos aprovechar el formato de en el fichero excel y obtener los datos por provincias.
#
# Comenzamos con los datos de afiliación a la SS.

# %% [markdown]
# ## Datos de afiliación a la Seguridad Social

# %% [markdown]
# Como es costumbre, comenzamos cargando las librerías necesarias y el fichero de afiliacion a la SS de noviembre de 2019, correspondiente a las elecciones generales celebradas ese mismo mes.

# %%
import pandas as pd
import numpy as np

# %%
seg_sol = pd.read_excel('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/SS_Paro/AfiliadosMuni-11-2019.xlsx', header = 1)

# %%
seg_sol.head()
# Out:
#         PROVINCIA               MUNICIPIO  ... R. E. M. Carbón TOTAL
# 0  01 ARABA/ÁLAVA  01001 ALEGRIA-DULANTZI  ...               0  >718
# 1  01 ARABA/ÁLAVA           01002 AMURRIO  ...               0  4186
# 2  01 ARABA/ÁLAVA           01003 ARAMAIO  ...               0  >246
# 3  01 ARABA/ÁLAVA        01004 ARTZINIEGA  ...               0  >377
# 4  01 ARABA/ÁLAVA           01006 ARMIÑON  ...               0   152
#
# [5 rows x 10 columns]

# %% [markdown]
# Vemos que tenemos el problema que los datos vienen como tipo objeto, debido a las entradas '<5'.

# %% [markdown]
# Por simplicidad, lo sustituimos en todo el df por el número 2, que pensamos puede ser bastante aproximado a la realidad.

# %%
seg_sol.dtypes
# Out:
# PROVINCIA              object
# MUNICIPIO              object
# TRAB                   object
# Reg. General(1)        object
# R. G.- S.E.Agrario     object
# R. G.- S.E.Hogar(2)    object
# R. E. MAR              object
# R. E. T. Autónomos     object
# R. E. M. Carbón        object
# TOTAL                  object
# dtype: object

# %%
seg_sol.replace('<5', '2')
# Out:
#                                               PROVINCIA  ... TOTAL
# 0                                        01 ARABA/ÁLAVA  ...  >718
# 1                                        01 ARABA/ÁLAVA  ...  4186
# 2                                        01 ARABA/ÁLAVA  ...  >246
# 3                                        01 ARABA/ÁLAVA  ...  >377
# 4                                        01 ARABA/ÁLAVA  ...   152
# ...                                                 ...  ...   ...
# 8225                                                NaN  ...   NaN
# 8226                                                NaN  ...   NaN
# 8227  (*) SIN DISTRIBUCIÓN: Incluye Cuidadores no Pr...  ...   NaN
# 8228  (1) Régimen General: No se incluyen datos de l...  ...   NaN
# 8229  (2) Desde enero 2013 en el Sistema Especial de...  ...   NaN
#
# [8230 rows x 10 columns]

# %% [markdown]
# Por otro lado nos encontramos con que pandas ha leido las celdas finales del fichero excel, que no nos interesan. Las suprimimos del df.

# %%
seg_sol[8190:8220]
# Out:
#         PROVINCIA                      MUNICIPIO  ... R. E. M. Carbón     TOTAL
# 8190  50 ZARAGOZA             50284 VILLAFELICHE  ...               0       >19
# 8191  50 ZARAGOZA      50285 VILLAFRANCA DE EBRO  ...               0      >170
# 8192  50 ZARAGOZA      50286 VILLALBA DE PEREJIL  ...               0        >0
# 8193  50 ZARAGOZA              50287 VILLALENGUA  ...               0       >70
# 8194  50 ZARAGOZA    50288 VILLANUEVA DE GALLEGO  ...               0      6314
# 8195  50 ZARAGOZA     50289 VILLANUEVA DE JILOCA  ...               0        >0
# 8196  50 ZARAGOZA     50290 VILLANUEVA DE HUERVA  ...               0       >91
# 8197  50 ZARAGOZA   50291 VILLAR DE LOS NAVARROS  ...               0       >10
# 8198  50 ZARAGOZA     50292 VILLARREAL DE HUERVA  ...               0      >251
# 8199  50 ZARAGOZA  50293 VILLARROYA DE LA SIERRA  ...               0       >64
# 8200  50 ZARAGOZA     50294 VILLARROYA DEL CAMPO  ...               0       >10
# 8201  50 ZARAGOZA               50296 ZAIDA (LA)  ...               0      >255
# 8202  50 ZARAGOZA                 50297 ZARAGOZA  ...              21    297766
# 8203  50 ZARAGOZA                    50298 ZUERA  ...               0      5632
# 8204  50 ZARAGOZA        50901 BIEL-FUENCALDERAS  ...               0       >36
# 8205  50 ZARAGOZA                 50902 MARRACOS  ...               0        >7
# 8206  50 ZARAGOZA    50903 VILLAMAYOR DE GALLEGO  ...               0       723
# 8207  50 ZARAGOZA                     PROVINCIAL  ...              21    425532
# 8208  50 ZARAGOZA           SIN DISTRIBUCIÓN (*)  ...               0      3875
# 8209     51 CEUTA                    51001 CEUTA  ...               0   >22.400
# 8210     51 CEUTA                     PROVINCIAL  ...               0   >22.540
# 8211     51 CEUTA           SIN DISTRIBUCIÓN (*)  ...               0      >139
# 8212   52 MELILLA                  52001 MELILLA  ...               0     23931
# 8213   52 MELILLA                     PROVINCIAL  ...               0     24242
# 8214   52 MELILLA           SIN DISTRIBUCIÓN (*)  ...               0      >602
# 8215     NACIONAL                            NaN  ...            1306  19415313
# 8216          NaN                            NaN  ...             NaN       NaN
# 8217          NaN                            NaN  ...             NaN       NaN
# 8218          NaN                            NaN  ...             NaN       NaN
# 8219          NaN                            NaN  ...             NaN       NaN
#
# [30 rows x 10 columns]

# %%
seg_sol = seg_sol[:8215].replace('<5', '2')

# %%
seg_sol
# Out:
#            PROVINCIA               MUNICIPIO  ... R. E. M. Carbón    TOTAL
# 0     01 ARABA/ÁLAVA  01001 ALEGRIA-DULANTZI  ...               0     >718
# 1     01 ARABA/ÁLAVA           01002 AMURRIO  ...               0     4186
# 2     01 ARABA/ÁLAVA           01003 ARAMAIO  ...               0     >246
# 3     01 ARABA/ÁLAVA        01004 ARTZINIEGA  ...               0     >377
# 4     01 ARABA/ÁLAVA           01006 ARMIÑON  ...               0      152
# ...              ...                     ...  ...             ...      ...
# 8210        51 CEUTA              PROVINCIAL  ...               0  >22.540
# 8211        51 CEUTA    SIN DISTRIBUCIÓN (*)  ...               0     >139
# 8212      52 MELILLA           52001 MELILLA  ...               0    23931
# 8213      52 MELILLA              PROVINCIAL  ...               0    24242
# 8214      52 MELILLA    SIN DISTRIBUCIÓN (*)  ...               0     >602
#
# [8215 rows x 10 columns]

# %% [markdown]
# Ahora tenemos que transformar las columnas que son legítimamente numéricas al tipo entero, para lo que utilizamos el método .to_mumeric

# %%
seg_sol.columns
# Out:
# Index(['PROVINCIA', 'MUNICIPIO', 'TRAB', 'Reg. General(1)',
#        'R. G.- S.E.Agrario', 'R. G.- S.E.Hogar(2)', 'R. E. MAR ',
#        'R. E. T. Autónomos', 'R. E. M. Carbón', 'TOTAL'],
#       dtype='object')

# %%
num = ['Reg. General(1)',
       'R. G.- S.E.Agrario', 'R. G.- S.E.Hogar(2)', 'R. E. MAR ',
       'R. E. T. Autónomos', 'R. E. M. Carbón']

# %%
seg_sol[num] = seg_sol[num].apply(pd.to_numeric, errors='coerce')

# %%
seg_sol.dtypes
# Out:
# PROVINCIA              object
# MUNICIPIO              object
# TRAB                   object
# Reg. General(1)         int64
# R. G.- S.E.Agrario      int64
# R. G.- S.E.Hogar(2)     int64
# R. E. MAR               int64
# R. E. T. Autónomos      int64
# R. E. M. Carbón         int64
# TOTAL                  object
# dtype: object

# %% [markdown]
# Creamos una columna con el total de afiliados, utilizando una comprehension.

# %%
seg_sol['Total_afiliados'] = sum(seg_sol[x] for x in num)

# %%
seg_sol
# Out:
#            PROVINCIA               MUNICIPIO  ...    TOTAL  Total_afiliados
# 0     01 ARABA/ÁLAVA  01001 ALEGRIA-DULANTZI  ...     >718              720
# 1     01 ARABA/ÁLAVA           01002 AMURRIO  ...     4186             4186
# 2     01 ARABA/ÁLAVA           01003 ARAMAIO  ...     >246              250
# 3     01 ARABA/ÁLAVA        01004 ARTZINIEGA  ...     >377              379
# 4     01 ARABA/ÁLAVA           01006 ARMIÑON  ...      152              152
# ...              ...                     ...  ...      ...              ...
# 8210        51 CEUTA              PROVINCIAL  ...  >22.540            22542
# 8211        51 CEUTA    SIN DISTRIBUCIÓN (*)  ...     >139              143
# 8212      52 MELILLA           52001 MELILLA  ...    23931            23931
# 8213      52 MELILLA              PROVINCIAL  ...    24242            24242
# 8214      52 MELILLA    SIN DISTRIBUCIÓN (*)  ...     >602              604
#
# [8215 rows x 11 columns]

# %%
seg_sol.columns
# Out:
# Index(['PROVINCIA', 'MUNICIPIO', 'TRAB', 'Reg. General(1)',
#        'R. G.- S.E.Agrario', 'R. G.- S.E.Hogar(2)', 'R. E. MAR ',
#        'R. E. T. Autónomos', 'R. E. M. Carbón', 'TOTAL', 'Total_afiliados'],
#       dtype='object')

# %%
seg_sol = seg_sol[['PROVINCIA', 'MUNICIPIO',  'Reg. General(1)',
       'R. G.- S.E.Agrario', 'R. G.- S.E.Hogar(2)', 'R. E. MAR ',
       'R. E. T. Autónomos', 'R. E. M. Carbón', 'Total_afiliados']]

# %% [markdown]
# Como hemos mencionado, aprovechamos la estructura del fichero excel para seleccionar por un lado los datos provinciales, que pueden sernos útiles más adelante. Lo hacemos seleccionando los registros que contengan la cadena 'PROVINCIAL'.

# %%
seg_sol_prov = seg_sol.loc[seg_sol['MUNICIPIO'] == 'PROVINCIAL']

# %%
seg_sol_prov
# Out:
#                       PROVINCIA   MUNICIPIO  ...  R. E. M. Carbón  Total_afiliados
# 51               01 ARABA/ÁLAVA  PROVINCIAL  ...                0           161503
# 140                 02 ALBACETE  PROVINCIAL  ...                0           141199
# 283         03 ALICANTE/ALACANT  PROVINCIAL  ...                0           667302
# 388                  04 ALMERIA  PROVINCIAL  ...                0           303977
# 638                    05 AVILA  PROVINCIAL  ...                0            53957
# 805                  06 BADAJOZ  PROVINCIAL  ...                0           248921
# 874            07 ILLES BALEARS  PROVINCIAL  ...                0           444791
# 1187               08 BARCELONA  PROVINCIAL  ...                0          2649276
# 1556                  09 BURGOS  PROVINCIAL  ...                0           148335
# 1781                 10 CACERES  PROVINCIAL  ...                0           143336
# 1828                   11 CADIZ  PROVINCIAL  ...                0           376465
# 1965      12 CASTELLÓN/CASTELLÓ  PROVINCIAL  ...                0           242599
# 2069             13 CIUDAD REAL  PROVINCIAL  ...                8           168052
# 2146                 14 CORDOBA  PROVINCIAL  ...                0           302310
# 2242                15 A CORUÑA  PROVINCIAL  ...                0           440075
# 2482                  16 CUENCA  PROVINCIAL  ...                0            77274
# 2705                  17 GIRONA  PROVINCIAL  ...                0           318994
# 2875                 18 GRANADA  PROVINCIAL  ...                0           338347
# 3163             19 GUADALAJARA  PROVINCIAL  ...                0            95552
# 3253                20 GIPUZKOA  PROVINCIAL  ...                0           328024
# 3334                  21 HUELVA  PROVINCIAL  ...                0           203556
# 3538                  22 HUESCA  PROVINCIAL  ...                0            97839
# 3637                    23 JAEN  PROVINCIAL  ...                0           243063
# 3850                    24 LEON  PROVINCIAL  ...              115           159504
# 4083                  25 LLEIDA  PROVINCIAL  ...                2           189081
# 4256                26 LA RIOJA  PROVINCIAL  ...                0           130383
# 4325                    27 LUGO  PROVINCIAL  ...                0           122700
# 4506                  28 MADRID  PROVINCIAL  ...                0          3304341
# 4611                  29 MALAGA  PROVINCIAL  ...                0           625522
# 4658                  30 MURCIA  PROVINCIAL  ...                0           591840
# 4932                 31 NAVARRA  PROVINCIAL  ...                0           291042
# 5026                 32 OURENSE  PROVINCIAL  ...                0           103583
# 5106                33 ASTURIAS  PROVINCIAL  ...             1114           368288
# 5299                34 PALENCIA  PROVINCIAL  ...                0            64934
# 5335              35 LAS PALMAS  PROVINCIAL  ...                0           437987
# 5399              36 PONTEVEDRA  PROVINCIAL  ...                0           358819
# 5763               37 SALAMANCA  PROVINCIAL  ...                0           120965
# 5819  38 SANTA CRUZ DE TENERIFE  PROVINCIAL  ...                0           389269
# 5923               39 CANTABRIA  PROVINCIAL  ...                0           219541
# 6134                 40 SEGOVIA  PROVINCIAL  ...                0            62313
# 6241                 41 SEVILLA  PROVINCIAL  ...                0           756765
# 6426                   42 SORIA  PROVINCIAL  ...                0            39391
# 6612               43 TARRAGONA  PROVINCIAL  ...                0           308537
# 6848                  44 TERUEL  PROVINCIAL  ...               47            55077
# 7054                  45 TOLEDO  PROVINCIAL  ...                0           233010
# 7323       46 VALENCIA/VALÈNCIA  PROVINCIAL  ...                0          1046183
# 7550              47 VALLADOLID  PROVINCIAL  ...                0           220358
# 7663                 48 BIZKAIA  PROVINCIAL  ...                0           490981
# 7913                  49 ZAMORA  PROVINCIAL  ...                0            57836
# 8207                50 ZARAGOZA  PROVINCIAL  ...               21           425532
# 8210                   51 CEUTA  PROVINCIAL  ...                0            22542
# 8213                 52 MELILLA  PROVINCIAL  ...                0            24242
#
# [52 rows x 9 columns]

# %%
seg_sol_prov.shape
# Out:
# (52, 9)

# %% [markdown]
# Ahora seleccionamos los datos de los municipios como tales, quitando los provinciales, nacionales, y los que, extrañamente, no tienen distribución. Obtenemos unos 8.110 registros, que tiene pinta se ser correcto.

# %%
seg_sol_muni = seg_sol.loc[seg_sol['MUNICIPIO'] != 'PROVINCIAL']
seg_sol_muni = seg_sol_muni.loc[seg_sol_muni['MUNICIPIO'] != 'SIN DISTRIBUCIÓN (*)']
seg_sol_muni = seg_sol_muni.loc[seg_sol_muni['PROVINCIA'] != 'NACIONAL']

# %%
seg_sol_muni
# Out:
#            PROVINCIA  ... Total_afiliados
# 0     01 ARABA/ÁLAVA  ...             720
# 1     01 ARABA/ÁLAVA  ...            4186
# 2     01 ARABA/ÁLAVA  ...             250
# 3     01 ARABA/ÁLAVA  ...             379
# 4     01 ARABA/ÁLAVA  ...             152
# ...              ...  ...             ...
# 8204     50 ZARAGOZA  ...              38
# 8205     50 ZARAGOZA  ...               9
# 8206     50 ZARAGOZA  ...             723
# 8209        51 CEUTA  ...           22402
# 8212      52 MELILLA  ...           23931
#
# [8111 rows x 9 columns]

# %%
seg_sol_muni['MUNICIPIO'].value_counts()
# Out:
# 45036 CARMENA                     1
# 16903 VALERAS (LAS)               1
# 39075 SANTANDER                   1
# 43906 AMPOLLA (L')                1
# 28135 SANTA MARIA DE LA ALAMED    1
#                                  ..
# 06046 ESPARRAGALEJO               1
# 09166 HORMAZAS (LAS)              1
# 34127 PERALES                     1
# 45042 CASASBUENAS                 1
# 09411 VALLE DE OCA                1
# Name: MUNICIPIO, Length: 8111, dtype: int64

# %% [markdown]
# Añadimos dos columnas con los códigos de los municipios, que nos serán útiles para hacer la unificación de los datos, y el numbre del municipio. Estos datos los extraemos de la columna 'MUNICIPIO'.

# %%
seg_sol_muni['cod_mun'] = seg_sol_muni['MUNICIPIO'].str[0:5]

# %%
seg_sol_muni['Municipio'] = seg_sol_muni['MUNICIPIO'].str[6:]

# %%
seg_sol_muni
# Out:
#            PROVINCIA  ...              Municipio
# 0     01 ARABA/ÁLAVA  ...       ALEGRIA-DULANTZI
# 1     01 ARABA/ÁLAVA  ...                AMURRIO
# 2     01 ARABA/ÁLAVA  ...                ARAMAIO
# 3     01 ARABA/ÁLAVA  ...             ARTZINIEGA
# 4     01 ARABA/ÁLAVA  ...                ARMIÑON
# ...              ...  ...                    ...
# 8204     50 ZARAGOZA  ...      BIEL-FUENCALDERAS
# 8205     50 ZARAGOZA  ...               MARRACOS
# 8206     50 ZARAGOZA  ...  VILLAMAYOR DE GALLEGO
# 8209        51 CEUTA  ...                  CEUTA
# 8212      52 MELILLA  ...                MELILLA
#
# [8111 rows x 11 columns]

# %% [markdown]
# Calculamos una nueva columna, la de la proporción de autónomos entre los afiliados, que pensamos puede estar correlacionada con el voto en unas elecciones.

# %%
seg_sol_muni['prop_autonomos'] = seg_sol_muni['R. E. T. Autónomos'] / seg_sol_muni['Total_afiliados']

# %%
seg_sol_muni
# Out:
#            PROVINCIA  ... prop_autonomos
# 0     01 ARABA/ÁLAVA  ...       0.288889
# 1     01 ARABA/ÁLAVA  ...       0.149546
# 2     01 ARABA/ÁLAVA  ...       0.228000
# 3     01 ARABA/ÁLAVA  ...       0.298153
# 4     01 ARABA/ÁLAVA  ...       0.131579
# ...              ...  ...            ...
# 8204     50 ZARAGOZA  ...       0.289474
# 8205     50 ZARAGOZA  ...       0.777778
# 8206     50 ZARAGOZA  ...       0.300138
# 8209        51 CEUTA  ...       0.149183
# 8212      52 MELILLA  ...       0.190548
#
# [8111 rows x 12 columns]

# %%
seg_sol_muni.columns
# Out:
# Index(['PROVINCIA', 'MUNICIPIO', 'Reg. General(1)', 'R. G.- S.E.Agrario',
#        'R. G.- S.E.Hogar(2)', 'R. E. MAR ', 'R. E. T. Autónomos',
#        'R. E. M. Carbón', 'Total_afiliados', 'cod_mun', 'Municipio',
#        'prop_autonomos'],
#       dtype='object')

# %% [markdown]
# Finalmente nos quedamos con las columnas que nos interesan realmente: la afiliación total y la proporción de autónomos., a parte de la definición de los municipios en sí mismos.

# %%
seg_sol_muni = seg_sol_muni[['PROVINCIA', 'cod_mun', 'Municipio', 'Total_afiliados',
       'prop_autonomos']]

# %%
seg_sol_muni.reset_index(drop = True)
# Out:
#            PROVINCIA cod_mun  ... Total_afiliados  prop_autonomos
# 0     01 ARABA/ÁLAVA   01001  ...             720        0.288889
# 1     01 ARABA/ÁLAVA   01002  ...            4186        0.149546
# 2     01 ARABA/ÁLAVA   01003  ...             250        0.228000
# 3     01 ARABA/ÁLAVA   01004  ...             379        0.298153
# 4     01 ARABA/ÁLAVA   01006  ...             152        0.131579
# ...              ...     ...  ...             ...             ...
# 8106     50 ZARAGOZA   50901  ...              38        0.289474
# 8107     50 ZARAGOZA   50902  ...               9        0.777778
# 8108     50 ZARAGOZA   50903  ...             723        0.300138
# 8109        51 CEUTA   51001  ...           22402        0.149183
# 8110      52 MELILLA   52001  ...           23931        0.190548
#
# [8111 rows x 5 columns]

# %%
seg_sol_muni
# Out:
#            PROVINCIA cod_mun  ... Total_afiliados  prop_autonomos
# 0     01 ARABA/ÁLAVA   01001  ...             720        0.288889
# 1     01 ARABA/ÁLAVA   01002  ...            4186        0.149546
# 2     01 ARABA/ÁLAVA   01003  ...             250        0.228000
# 3     01 ARABA/ÁLAVA   01004  ...             379        0.298153
# 4     01 ARABA/ÁLAVA   01006  ...             152        0.131579
# ...              ...     ...  ...             ...             ...
# 8204     50 ZARAGOZA   50901  ...              38        0.289474
# 8205     50 ZARAGOZA   50902  ...               9        0.777778
# 8206     50 ZARAGOZA   50903  ...             723        0.300138
# 8209        51 CEUTA   51001  ...           22402        0.149183
# 8212      52 MELILLA   52001  ...           23931        0.190548
#
# [8111 rows x 5 columns]

# %% [markdown]
# Finalmente guardamos los datos de afiliación a la Seguridad Social de los municipios, en este caso los correspondientes a noviembre 2019. Hicimos lo propio con los de las otras cuatro elecciones.

# %%
seg_sol_muni.to_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-19-Nov/seg_sol_muni_N19.txt', sep = ',', index = False)

# %% [markdown]
# Ahora vamos con los datos provinciales, donde básicamente hacemos lo mismo que con los municipales. Comenzamos creando una columna con el código de provincia y a continuación otra con el nombre de éstas.

# %%
seg_sol_prov['cod_prov'] = seg_sol_prov['PROVINCIA'].str[0:2]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
seg_sol_prov
# Out:
#                       PROVINCIA   MUNICIPIO  ...  Total_afiliados  cod_prov
# 51               01 ARABA/ÁLAVA  PROVINCIAL  ...           161503        01
# 140                 02 ALBACETE  PROVINCIAL  ...           141199        02
# 283         03 ALICANTE/ALACANT  PROVINCIAL  ...           667302        03
# 388                  04 ALMERIA  PROVINCIAL  ...           303977        04
# 638                    05 AVILA  PROVINCIAL  ...            53957        05
# 805                  06 BADAJOZ  PROVINCIAL  ...           248921        06
# 874            07 ILLES BALEARS  PROVINCIAL  ...           444791        07
# 1187               08 BARCELONA  PROVINCIAL  ...          2649276        08
# 1556                  09 BURGOS  PROVINCIAL  ...           148335        09
# 1781                 10 CACERES  PROVINCIAL  ...           143336        10
# 1828                   11 CADIZ  PROVINCIAL  ...           376465        11
# 1965      12 CASTELLÓN/CASTELLÓ  PROVINCIAL  ...           242599        12
# 2069             13 CIUDAD REAL  PROVINCIAL  ...           168052        13
# 2146                 14 CORDOBA  PROVINCIAL  ...           302310        14
# 2242                15 A CORUÑA  PROVINCIAL  ...           440075        15
# 2482                  16 CUENCA  PROVINCIAL  ...            77274        16
# 2705                  17 GIRONA  PROVINCIAL  ...           318994        17
# 2875                 18 GRANADA  PROVINCIAL  ...           338347        18
# 3163             19 GUADALAJARA  PROVINCIAL  ...            95552        19
# 3253                20 GIPUZKOA  PROVINCIAL  ...           328024        20
# 3334                  21 HUELVA  PROVINCIAL  ...           203556        21
# 3538                  22 HUESCA  PROVINCIAL  ...            97839        22
# 3637                    23 JAEN  PROVINCIAL  ...           243063        23
# 3850                    24 LEON  PROVINCIAL  ...           159504        24
# 4083                  25 LLEIDA  PROVINCIAL  ...           189081        25
# 4256                26 LA RIOJA  PROVINCIAL  ...           130383        26
# 4325                    27 LUGO  PROVINCIAL  ...           122700        27
# 4506                  28 MADRID  PROVINCIAL  ...          3304341        28
# 4611                  29 MALAGA  PROVINCIAL  ...           625522        29
# 4658                  30 MURCIA  PROVINCIAL  ...           591840        30
# 4932                 31 NAVARRA  PROVINCIAL  ...           291042        31
# 5026                 32 OURENSE  PROVINCIAL  ...           103583        32
# 5106                33 ASTURIAS  PROVINCIAL  ...           368288        33
# 5299                34 PALENCIA  PROVINCIAL  ...            64934        34
# 5335              35 LAS PALMAS  PROVINCIAL  ...           437987        35
# 5399              36 PONTEVEDRA  PROVINCIAL  ...           358819        36
# 5763               37 SALAMANCA  PROVINCIAL  ...           120965        37
# 5819  38 SANTA CRUZ DE TENERIFE  PROVINCIAL  ...           389269        38
# 5923               39 CANTABRIA  PROVINCIAL  ...           219541        39
# 6134                 40 SEGOVIA  PROVINCIAL  ...            62313        40
# 6241                 41 SEVILLA  PROVINCIAL  ...           756765        41
# 6426                   42 SORIA  PROVINCIAL  ...            39391        42
# 6612               43 TARRAGONA  PROVINCIAL  ...           308537        43
# 6848                  44 TERUEL  PROVINCIAL  ...            55077        44
# 7054                  45 TOLEDO  PROVINCIAL  ...           233010        45
# 7323       46 VALENCIA/VALÈNCIA  PROVINCIAL  ...          1046183        46
# 7550              47 VALLADOLID  PROVINCIAL  ...           220358        47
# 7663                 48 BIZKAIA  PROVINCIAL  ...           490981        48
# 7913                  49 ZAMORA  PROVINCIAL  ...            57836        49
# 8207                50 ZARAGOZA  PROVINCIAL  ...           425532        50
# 8210                   51 CEUTA  PROVINCIAL  ...            22542        51
# 8213                 52 MELILLA  PROVINCIAL  ...            24242        52
#
# [52 rows x 10 columns]

# %%
seg_sol_prov['Provincia'] = seg_sol_prov['PROVINCIA'].str[3:]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
seg_sol_prov
# Out:
#                       PROVINCIA   MUNICIPIO  ...  cod_prov               Provincia
# 51               01 ARABA/ÁLAVA  PROVINCIAL  ...        01             ARABA/ÁLAVA
# 140                 02 ALBACETE  PROVINCIAL  ...        02                ALBACETE
# 283         03 ALICANTE/ALACANT  PROVINCIAL  ...        03        ALICANTE/ALACANT
# 388                  04 ALMERIA  PROVINCIAL  ...        04                 ALMERIA
# 638                    05 AVILA  PROVINCIAL  ...        05                   AVILA
# 805                  06 BADAJOZ  PROVINCIAL  ...        06                 BADAJOZ
# 874            07 ILLES BALEARS  PROVINCIAL  ...        07           ILLES BALEARS
# 1187               08 BARCELONA  PROVINCIAL  ...        08               BARCELONA
# 1556                  09 BURGOS  PROVINCIAL  ...        09                  BURGOS
# 1781                 10 CACERES  PROVINCIAL  ...        10                 CACERES
# 1828                   11 CADIZ  PROVINCIAL  ...        11                   CADIZ
# 1965      12 CASTELLÓN/CASTELLÓ  PROVINCIAL  ...        12      CASTELLÓN/CASTELLÓ
# 2069             13 CIUDAD REAL  PROVINCIAL  ...        13             CIUDAD REAL
# 2146                 14 CORDOBA  PROVINCIAL  ...        14                 CORDOBA
# 2242                15 A CORUÑA  PROVINCIAL  ...        15                A CORUÑA
# 2482                  16 CUENCA  PROVINCIAL  ...        16                  CUENCA
# 2705                  17 GIRONA  PROVINCIAL  ...        17                  GIRONA
# 2875                 18 GRANADA  PROVINCIAL  ...        18                 GRANADA
# 3163             19 GUADALAJARA  PROVINCIAL  ...        19             GUADALAJARA
# 3253                20 GIPUZKOA  PROVINCIAL  ...        20                GIPUZKOA
# 3334                  21 HUELVA  PROVINCIAL  ...        21                  HUELVA
# 3538                  22 HUESCA  PROVINCIAL  ...        22                  HUESCA
# 3637                    23 JAEN  PROVINCIAL  ...        23                    JAEN
# 3850                    24 LEON  PROVINCIAL  ...        24                    LEON
# 4083                  25 LLEIDA  PROVINCIAL  ...        25                  LLEIDA
# 4256                26 LA RIOJA  PROVINCIAL  ...        26                LA RIOJA
# 4325                    27 LUGO  PROVINCIAL  ...        27                    LUGO
# 4506                  28 MADRID  PROVINCIAL  ...        28                  MADRID
# 4611                  29 MALAGA  PROVINCIAL  ...        29                  MALAGA
# 4658                  30 MURCIA  PROVINCIAL  ...        30                  MURCIA
# 4932                 31 NAVARRA  PROVINCIAL  ...        31                 NAVARRA
# 5026                 32 OURENSE  PROVINCIAL  ...        32                 OURENSE
# 5106                33 ASTURIAS  PROVINCIAL  ...        33                ASTURIAS
# 5299                34 PALENCIA  PROVINCIAL  ...        34                PALENCIA
# 5335              35 LAS PALMAS  PROVINCIAL  ...        35              LAS PALMAS
# 5399              36 PONTEVEDRA  PROVINCIAL  ...        36              PONTEVEDRA
# 5763               37 SALAMANCA  PROVINCIAL  ...        37               SALAMANCA
# 5819  38 SANTA CRUZ DE TENERIFE  PROVINCIAL  ...        38  SANTA CRUZ DE TENERIFE
# 5923               39 CANTABRIA  PROVINCIAL  ...        39               CANTABRIA
# 6134                 40 SEGOVIA  PROVINCIAL  ...        40                 SEGOVIA
# 6241                 41 SEVILLA  PROVINCIAL  ...        41                 SEVILLA
# 6426                   42 SORIA  PROVINCIAL  ...        42                   SORIA
# 6612               43 TARRAGONA  PROVINCIAL  ...        43               TARRAGONA
# 6848                  44 TERUEL  PROVINCIAL  ...        44                  TERUEL
# 7054                  45 TOLEDO  PROVINCIAL  ...        45                  TOLEDO
# 7323       46 VALENCIA/VALÈNCIA  PROVINCIAL  ...        46       VALENCIA/VALÈNCIA
# 7550              47 VALLADOLID  PROVINCIAL  ...        47              VALLADOLID
# 7663                 48 BIZKAIA  PROVINCIAL  ...        48                 BIZKAIA
# 7913                  49 ZAMORA  PROVINCIAL  ...        49                  ZAMORA
# 8207                50 ZARAGOZA  PROVINCIAL  ...        50                ZARAGOZA
# 8210                   51 CEUTA  PROVINCIAL  ...        51                   CEUTA
# 8213                 52 MELILLA  PROVINCIAL  ...        52                 MELILLA
#
# [52 rows x 11 columns]

# %% [markdown]
# También en las provincias añadimos la columna de la proporción de afiliados a la SS que son autónomos.

# %%
seg_sol_prov['prop_autonomos'] = seg_sol_prov['R. E. T. Autónomos'] / seg_sol_prov['Total_afiliados']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
seg_sol_prov
# Out:
#                       PROVINCIA  ... prop_autonomos
# 51               01 ARABA/ÁLAVA  ...       0.126821
# 140                 02 ALBACETE  ...       0.211630
# 283         03 ALICANTE/ALACANT  ...       0.198974
# 388                  04 ALMERIA  ...       0.195732
# 638                    05 AVILA  ...       0.264377
# 805                  06 BADAJOZ  ...       0.197733
# 874            07 ILLES BALEARS  ...       0.205148
# 1187               08 BARCELONA  ...       0.150032
# 1556                  09 BURGOS  ...       0.185600
# 1781                 10 CACERES  ...       0.218459
# 1828                   11 CADIZ  ...       0.162615
# 1965      12 CASTELLÓN/CASTELLÓ  ...       0.168624
# 2069             13 CIUDAD REAL  ...       0.212226
# 2146                 14 CORDOBA  ...       0.174652
# 2242                15 A CORUÑA  ...       0.193647
# 2482                  16 CUENCA  ...       0.243678
# 2705                  17 GIRONA  ...       0.188743
# 2875                 18 GRANADA  ...       0.191440
# 3163             19 GUADALAJARA  ...       0.157705
# 3253                20 GIPUZKOA  ...       0.202848
# 3334                  21 HUELVA  ...       0.136980
# 3538                  22 HUESCA  ...       0.225892
# 3637                    23 JAEN  ...       0.170199
# 3850                    24 LEON  ...       0.229725
# 4083                  25 LLEIDA  ...       0.205029
# 4256                26 LA RIOJA  ...       0.197311
# 4325                    27 LUGO  ...       0.274564
# 4506                  28 MADRID  ...       0.123297
# 4611                  29 MALAGA  ...       0.192027
# 4658                  30 MURCIA  ...       0.169458
# 4932                 31 NAVARRA  ...       0.162197
# 5026                 32 OURENSE  ...       0.227885
# 5106                33 ASTURIAS  ...       0.198605
# 5299                34 PALENCIA  ...       0.203160
# 5335              35 LAS PALMAS  ...       0.148792
# 5399              36 PONTEVEDRA  ...       0.186757
# 5763               37 SALAMANCA  ...       0.218881
# 5819  38 SANTA CRUZ DE TENERIFE  ...       0.163930
# 5923               39 CANTABRIA  ...       0.188502
# 6134                 40 SEGOVIA  ...       0.229840
# 6241                 41 SEVILLA  ...       0.147568
# 6426                   42 SORIA  ...       0.200046
# 6612               43 TARRAGONA  ...       0.174692
# 6848                  44 TERUEL  ...       0.240409
# 7054                  45 TOLEDO  ...       0.213566
# 7323       46 VALENCIA/VALÈNCIA  ...       0.170639
# 7550              47 VALLADOLID  ...       0.163729
# 7663                 48 BIZKAIA  ...       0.170758
# 7913                  49 ZAMORA  ...       0.290632
# 8207                50 ZARAGOZA  ...       0.155850
# 8210                   51 CEUTA  ...       0.150386
# 8213                 52 MELILLA  ...       0.193878
#
# [52 rows x 12 columns]

# %%
seg_sol_prov.reset_index()
# Out:
#     index                  PROVINCIA  ...               Provincia  prop_autonomos
# 0      51             01 ARABA/ÁLAVA  ...             ARABA/ÁLAVA        0.126821
# 1     140                02 ALBACETE  ...                ALBACETE        0.211630
# 2     283        03 ALICANTE/ALACANT  ...        ALICANTE/ALACANT        0.198974
# 3     388                 04 ALMERIA  ...                 ALMERIA        0.195732
# 4     638                   05 AVILA  ...                   AVILA        0.264377
# 5     805                 06 BADAJOZ  ...                 BADAJOZ        0.197733
# 6     874           07 ILLES BALEARS  ...           ILLES BALEARS        0.205148
# 7    1187               08 BARCELONA  ...               BARCELONA        0.150032
# 8    1556                  09 BURGOS  ...                  BURGOS        0.185600
# 9    1781                 10 CACERES  ...                 CACERES        0.218459
# 10   1828                   11 CADIZ  ...                   CADIZ        0.162615
# 11   1965      12 CASTELLÓN/CASTELLÓ  ...      CASTELLÓN/CASTELLÓ        0.168624
# 12   2069             13 CIUDAD REAL  ...             CIUDAD REAL        0.212226
# 13   2146                 14 CORDOBA  ...                 CORDOBA        0.174652
# 14   2242                15 A CORUÑA  ...                A CORUÑA        0.193647
# 15   2482                  16 CUENCA  ...                  CUENCA        0.243678
# 16   2705                  17 GIRONA  ...                  GIRONA        0.188743
# 17   2875                 18 GRANADA  ...                 GRANADA        0.191440
# 18   3163             19 GUADALAJARA  ...             GUADALAJARA        0.157705
# 19   3253                20 GIPUZKOA  ...                GIPUZKOA        0.202848
# 20   3334                  21 HUELVA  ...                  HUELVA        0.136980
# 21   3538                  22 HUESCA  ...                  HUESCA        0.225892
# 22   3637                    23 JAEN  ...                    JAEN        0.170199
# 23   3850                    24 LEON  ...                    LEON        0.229725
# 24   4083                  25 LLEIDA  ...                  LLEIDA        0.205029
# 25   4256                26 LA RIOJA  ...                LA RIOJA        0.197311
# 26   4325                    27 LUGO  ...                    LUGO        0.274564
# 27   4506                  28 MADRID  ...                  MADRID        0.123297
# 28   4611                  29 MALAGA  ...                  MALAGA        0.192027
# 29   4658                  30 MURCIA  ...                  MURCIA        0.169458
# 30   4932                 31 NAVARRA  ...                 NAVARRA        0.162197
# 31   5026                 32 OURENSE  ...                 OURENSE        0.227885
# 32   5106                33 ASTURIAS  ...                ASTURIAS        0.198605
# 33   5299                34 PALENCIA  ...                PALENCIA        0.203160
# 34   5335              35 LAS PALMAS  ...              LAS PALMAS        0.148792
# 35   5399              36 PONTEVEDRA  ...              PONTEVEDRA        0.186757
# 36   5763               37 SALAMANCA  ...               SALAMANCA        0.218881
# 37   5819  38 SANTA CRUZ DE TENERIFE  ...  SANTA CRUZ DE TENERIFE        0.163930
# 38   5923               39 CANTABRIA  ...               CANTABRIA        0.188502
# 39   6134                 40 SEGOVIA  ...                 SEGOVIA        0.229840
# 40   6241                 41 SEVILLA  ...                 SEVILLA        0.147568
# 41   6426                   42 SORIA  ...                   SORIA        0.200046
# 42   6612               43 TARRAGONA  ...               TARRAGONA        0.174692
# 43   6848                  44 TERUEL  ...                  TERUEL        0.240409
# 44   7054                  45 TOLEDO  ...                  TOLEDO        0.213566
# 45   7323       46 VALENCIA/VALÈNCIA  ...       VALENCIA/VALÈNCIA        0.170639
# 46   7550              47 VALLADOLID  ...              VALLADOLID        0.163729
# 47   7663                 48 BIZKAIA  ...                 BIZKAIA        0.170758
# 48   7913                  49 ZAMORA  ...                  ZAMORA        0.290632
# 49   8207                50 ZARAGOZA  ...                ZARAGOZA        0.155850
# 50   8210                   51 CEUTA  ...                   CEUTA        0.150386
# 51   8213                 52 MELILLA  ...                 MELILLA        0.193878
#
# [52 rows x 13 columns]

# %% [markdown]
# Tras resetear el índice, seleccionamos las columnas que nos interesan, que son las mismas que en el caso de los municipios.

# %%
seg_sol_prov.columns
# Out:
# Index(['PROVINCIA', 'MUNICIPIO', 'Reg. General(1)', 'R. G.- S.E.Agrario',
#        'R. G.- S.E.Hogar(2)', 'R. E. MAR ', 'R. E. T. Autónomos',
#        'R. E. M. Carbón', 'Total_afiliados', 'cod_prov', 'Provincia',
#        'prop_autonomos'],
#       dtype='object')

# %%
seg_sol_prov = seg_sol_prov[['cod_prov', 'Provincia', 'Total_afiliados', 'prop_autonomos']]

# %%
seg_sol_prov.reset_index(drop = True)
# Out:
#    cod_prov               Provincia  Total_afiliados  prop_autonomos
# 0        01             ARABA/ÁLAVA           161503        0.126821
# 1        02                ALBACETE           141199        0.211630
# 2        03        ALICANTE/ALACANT           667302        0.198974
# 3        04                 ALMERIA           303977        0.195732
# 4        05                   AVILA            53957        0.264377
# 5        06                 BADAJOZ           248921        0.197733
# 6        07           ILLES BALEARS           444791        0.205148
# 7        08               BARCELONA          2649276        0.150032
# 8        09                  BURGOS           148335        0.185600
# 9        10                 CACERES           143336        0.218459
# 10       11                   CADIZ           376465        0.162615
# 11       12      CASTELLÓN/CASTELLÓ           242599        0.168624
# 12       13             CIUDAD REAL           168052        0.212226
# 13       14                 CORDOBA           302310        0.174652
# 14       15                A CORUÑA           440075        0.193647
# 15       16                  CUENCA            77274        0.243678
# 16       17                  GIRONA           318994        0.188743
# 17       18                 GRANADA           338347        0.191440
# 18       19             GUADALAJARA            95552        0.157705
# 19       20                GIPUZKOA           328024        0.202848
# 20       21                  HUELVA           203556        0.136980
# 21       22                  HUESCA            97839        0.225892
# 22       23                    JAEN           243063        0.170199
# 23       24                    LEON           159504        0.229725
# 24       25                  LLEIDA           189081        0.205029
# 25       26                LA RIOJA           130383        0.197311
# 26       27                    LUGO           122700        0.274564
# 27       28                  MADRID          3304341        0.123297
# 28       29                  MALAGA           625522        0.192027
# 29       30                  MURCIA           591840        0.169458
# 30       31                 NAVARRA           291042        0.162197
# 31       32                 OURENSE           103583        0.227885
# 32       33                ASTURIAS           368288        0.198605
# 33       34                PALENCIA            64934        0.203160
# 34       35              LAS PALMAS           437987        0.148792
# 35       36              PONTEVEDRA           358819        0.186757
# 36       37               SALAMANCA           120965        0.218881
# 37       38  SANTA CRUZ DE TENERIFE           389269        0.163930
# 38       39               CANTABRIA           219541        0.188502
# 39       40                 SEGOVIA            62313        0.229840
# 40       41                 SEVILLA           756765        0.147568
# 41       42                   SORIA            39391        0.200046
# 42       43               TARRAGONA           308537        0.174692
# 43       44                  TERUEL            55077        0.240409
# 44       45                  TOLEDO           233010        0.213566
# 45       46       VALENCIA/VALÈNCIA          1046183        0.170639
# 46       47              VALLADOLID           220358        0.163729
# 47       48                 BIZKAIA           490981        0.170758
# 48       49                  ZAMORA            57836        0.290632
# 49       50                ZARAGOZA           425532        0.155850
# 50       51                   CEUTA            22542        0.150386
# 51       52                 MELILLA            24242        0.193878

# %% [markdown]
# Finalmente guardamos el dataset, que de nuevo habra uno por elección. En el nombre dejamos claro que se trata de datos provinciales.

# %%
seg_sol_prov.to_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-19-Nov/seg_sol_prov_N19.txt', sep = ',', index = False)

# %% [markdown]
# ## Datos de paro

# %% [markdown]
# Ahora examinamos los datos del paro, que también se expreasan por municipio, aunque en esta ocasión no podremos extraer los agregados por provincias directamente.

# %% [markdown]
# Comenzamos intentando que pandas nos carge los códigos geográficos en forma de strings.

# %%
cols_str = ['Código de CA', 'Codigo Provincia', 'Codigo Municipio']

# %%
dict_str = { x : 'str' for x in cols_str}

# %%
dict_str
# Out:
# {'Codigo Municipio': 'str', 'Codigo Provincia': 'str', 'Código de CA': 'str'}

# %%
paro = pd.read_excel('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/SS_Paro/Dtes_empleo_por_municipios_segundo_semestre_2019_xls.xls', 
                     header = 1, dtype = dict_str)

# %% [markdown]
# Sin embargo vemos que estos códigos estaban con el formato incorrecto ya en origen (fichero excel). Para corregirlo echamos mano del método .zfill()

# %%
paro
# Out:
#        Código mes   ... Dtes Empleo Sin empleo Anterior
# 0           201907  ...                               3
# 1           201907  ...                               9
# 2           201907  ...                             229
# 3           201907  ...                               2
# 4           201907  ...                               2
# ...            ...  ...                             ...
# 48757       201912  ...                               0
# 48758       201912  ...                               0
# 48759       201912  ...                               0
# 48760       201912  ...                            2405
# 48761       201912  ...                            2497
#
# [48762 rows x 20 columns]

# %%
paro.dtypes
# Out:
# Código mes                          int64
# mes                                object
# Código de CA                       object
# Comunidad Autónoma                 object
# Codigo Provincia                   object
# Provincia                          object
# Codigo Municipio                   object
#  Municipio                         object
# total Dtes Empleo                   int64
# Dtes Empleo hombre edad < 25        int64
# Dtes Empleo hombre edad 25 -45      int64
# Dtes Empleo hombre edad >=45        int64
# Dtes Empleo mujer edad < 25         int64
# Dtes Empleo mujer edad 25 -45       int64
# Dtes Empleo mujer edad >=45         int64
# Dtes EmpleoAgricultura              int64
# Dtes Empleo Industria               int64
# Dtes Empleo Construcción            int64
# Dtes Empleo Servicios               int64
# Dtes Empleo Sin empleo Anterior     int64
# dtype: object

# %%
paro["Código de CA"]= paro["Código de CA"].str.zfill(2)

# %%
paro["Codigo Provincia"]= paro["Codigo Provincia"].str.zfill(2)
paro["Codigo Municipio"]= paro["Codigo Municipio"].str.zfill(5)

# %% [markdown]
# Ahora sí que los códigos de provincia, CCAA y municipio parecen tener un formato adecuado.

# %%
paro
# Out:
#        Código mes   ... Dtes Empleo Sin empleo Anterior
# 0           201907  ...                               3
# 1           201907  ...                               9
# 2           201907  ...                             229
# 3           201907  ...                               2
# 4           201907  ...                               2
# ...            ...  ...                             ...
# 48757       201912  ...                               0
# 48758       201912  ...                               0
# 48759       201912  ...                               0
# 48760       201912  ...                            2405
# 48761       201912  ...                            2497
#
# [48762 rows x 20 columns]

# %% [markdown]
# Los ficheros excel que proporciona el SEPE están agregados por semestres, en este caso el 2º de 2019. Seleccionamos los datos correspondientes a noviembre de 2019.

# %%
paro = paro.loc[paro['Código mes '] == 201911]

# %%
paro
# Out:
#        Código mes   ... Dtes Empleo Sin empleo Anterior
# 32508       201911  ...                               8
# 32509       201911  ...                               7
# 32510       201911  ...                             229
# 32511       201911  ...                               1
# 32512       201911  ...                               2
# ...            ...  ...                             ...
# 40630       201911  ...                               0
# 40631       201911  ...                               0
# 40632       201911  ...                               0
# 40633       201911  ...                            2467
# 40634       201911  ...                            2560
#
# [8127 rows x 20 columns]

# %%
paro.columns
# Out:
# Index(['Código mes ', 'mes', 'Código de CA', 'Comunidad Autónoma',
#        'Codigo Provincia', 'Provincia', 'Codigo Municipio', ' Municipio',
#        'total Dtes Empleo', 'Dtes Empleo hombre edad < 25',
#        'Dtes Empleo hombre edad 25 -45 ', 'Dtes Empleo hombre edad >=45',
#        'Dtes Empleo mujer edad < 25', 'Dtes Empleo mujer edad 25 -45 ',
#        'Dtes Empleo mujer edad >=45', 'Dtes EmpleoAgricultura',
#        'Dtes Empleo Industria', 'Dtes Empleo Construcción',
#        'Dtes Empleo Servicios', 'Dtes Empleo Sin empleo Anterior'],
#       dtype='object')

# %% [markdown]
# Pensamos que igual es interesante la variable de distribución de paro total por sexos, que no viene explicitada, por lo que la definimos nosotros, sumando las correspondientes a las edades.

# %%
paro['prop_hombres'] = (paro['Dtes Empleo hombre edad 25 -45 '] + 
                        paro['Dtes Empleo hombre edad < 25'] + 
                        paro['Dtes Empleo hombre edad >=45']) / paro['total Dtes Empleo']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
paro
# Out:
#        Código mes   ... prop_hombres
# 32508       201911  ...     0.421429
# 32509       201911  ...     0.379888
# 32510       201911  ...     0.432871
# 32511       201911  ...     0.606061
# 32512       201911  ...     0.423077
# ...            ...  ...          ...
# 40630       201911  ...     0.500000
# 40631       201911  ...          NaN
# 40632       201911  ...     0.600000
# 40633       201911  ...     0.403607
# 40634       201911  ...     0.366177
#
# [8127 rows x 21 columns]

# %% [markdown]
# Para esta columna asumimos un 50% de proporción de hombres en aquellos municipios en los que no hay datos.

# %%
paro['prop_hombres'] = paro['prop_hombres'].replace(np.nan, 0.5, regex=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
paro
# Out:
#        Código mes   ... prop_hombres
# 32508       201911  ...     0.421429
# 32509       201911  ...     0.379888
# 32510       201911  ...     0.432871
# 32511       201911  ...     0.606061
# 32512       201911  ...     0.423077
# ...            ...  ...          ...
# 40630       201911  ...     0.500000
# 40631       201911  ...     0.500000
# 40632       201911  ...     0.600000
# 40633       201911  ...     0.403607
# 40634       201911  ...     0.366177
#
# [8127 rows x 21 columns]

# %% [markdown]
# También parece interesante la proporción de parados que tienen más de 45 años, sean hombres o mujeres. Definimos también esta columna.

# %%
paro['mayores_45'] = (paro['Dtes Empleo hombre edad >=45'] + paro['Dtes Empleo mujer edad >=45']) / paro['total Dtes Empleo']
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
paro
# Out:
#        Código mes                 mes  ... prop_hombres mayores_45
# 32508       201911  Noviembre de 2019  ...     0.421429   0.550000
# 32509       201911  Noviembre de 2019  ...     0.379888   0.625698
# 32510       201911  Noviembre de 2019  ...     0.432871   0.473663
# 32511       201911  Noviembre de 2019  ...     0.606061   0.757576
# 32512       201911  Noviembre de 2019  ...     0.423077   0.564103
# ...            ...                ...  ...          ...        ...
# 40630       201911  Noviembre de 2019  ...     0.500000   0.500000
# 40631       201911  Noviembre de 2019  ...     0.500000        NaN
# 40632       201911  Noviembre de 2019  ...     0.600000   0.600000
# 40633       201911  Noviembre de 2019  ...     0.403607   0.404116
# 40634       201911  Noviembre de 2019  ...     0.366177   0.403627
#
# [8127 rows x 22 columns]

# %%
paro.columns
# Out:
# Index(['Código mes ', 'mes', 'Código de CA', 'Comunidad Autónoma',
#        'Codigo Provincia', 'Provincia', 'Codigo Municipio', ' Municipio',
#        'total Dtes Empleo', 'Dtes Empleo hombre edad < 25',
#        'Dtes Empleo hombre edad 25 -45 ', 'Dtes Empleo hombre edad >=45',
#        'Dtes Empleo mujer edad < 25', 'Dtes Empleo mujer edad 25 -45 ',
#        'Dtes Empleo mujer edad >=45', 'Dtes EmpleoAgricultura',
#        'Dtes Empleo Industria', 'Dtes Empleo Construcción',
#        'Dtes Empleo Servicios', 'Dtes Empleo Sin empleo Anterior',
#        'prop_hombres', 'mayores_45'],
#       dtype='object')

# %% [markdown]
# A continuación renombramos varias columnas, principalmente códigos geográficos, que serán comunes con otras bases de datos, y que nos ayudarán a la hora de unificarlos.

# %%
paro = paro.rename(columns={"Comunidad Autónoma": "CCAA", 'Código de CA': 'cod_ccaa', 'Codigo Provincia': 'cod_prov', 'Codigo Municipio': 'cod_mun' }, errors="raise")

# %%
paro
# Out:
#        Código mes                 mes  ... prop_hombres mayores_45
# 32508       201911  Noviembre de 2019  ...     0.421429   0.550000
# 32509       201911  Noviembre de 2019  ...     0.379888   0.625698
# 32510       201911  Noviembre de 2019  ...     0.432871   0.473663
# 32511       201911  Noviembre de 2019  ...     0.606061   0.757576
# 32512       201911  Noviembre de 2019  ...     0.423077   0.564103
# ...            ...                ...  ...          ...        ...
# 40630       201911  Noviembre de 2019  ...     0.500000   0.500000
# 40631       201911  Noviembre de 2019  ...     0.500000        NaN
# 40632       201911  Noviembre de 2019  ...     0.600000   0.600000
# 40633       201911  Noviembre de 2019  ...     0.403607   0.404116
# 40634       201911  Noviembre de 2019  ...     0.366177   0.403627
#
# [8127 rows x 22 columns]

# %% [markdown]
# Pequeñas rectificaciones a los nombres de las columnas:

# %%
paro = paro.rename(columns={"mayores_45": "prop_mayores_45"}, errors="raise")

# %%
paro = paro.rename(columns={' Municipio': 'Municipio'}, errors="raise")

# %%
paro.columns
# Out:
# Index(['Código mes ', 'mes', 'cod_ccaa', 'CCAA', 'cod_prov', 'Provincia',
#        'cod_mun', 'Municipio', 'total Dtes Empleo',
#        'Dtes Empleo hombre edad < 25', 'Dtes Empleo hombre edad 25 -45 ',
#        'Dtes Empleo hombre edad >=45', 'Dtes Empleo mujer edad < 25',
#        'Dtes Empleo mujer edad 25 -45 ', 'Dtes Empleo mujer edad >=45',
#        'Dtes EmpleoAgricultura', 'Dtes Empleo Industria',
#        'Dtes Empleo Construcción', 'Dtes Empleo Servicios',
#        'Dtes Empleo Sin empleo Anterior', 'prop_hombres', 'prop_mayores_45'],
#       dtype='object')

# %% [markdown]
# Seleccionamos los nombres de las columnas que realmente nos interesan

# %%
paro = paro[['Código mes ', 'cod_ccaa', 'CCAA', 'cod_prov', 'Provincia',
       'cod_mun', 'Municipio', 'total Dtes Empleo', 'prop_hombres', 'prop_mayores_45']]

# %%
paro
# Out:
#        Código mes  cod_ccaa  ... prop_hombres prop_mayores_45
# 32508       201911       01  ...     0.421429        0.550000
# 32509       201911       01  ...     0.379888        0.625698
# 32510       201911       01  ...     0.432871        0.473663
# 32511       201911       01  ...     0.606061        0.757576
# 32512       201911       01  ...     0.423077        0.564103
# ...            ...      ...  ...          ...             ...
# 40630       201911       17  ...     0.500000        0.500000
# 40631       201911       17  ...     0.500000             NaN
# 40632       201911       17  ...     0.600000        0.600000
# 40633       201911       18  ...     0.403607        0.404116
# 40634       201911       19  ...     0.366177        0.403627
#
# [8127 rows x 10 columns]

# %% [markdown]
# Rellenamos brevemente algunos NaN de la columna de la proporción de parados de más de 45 años.

# %%
paro['prop_mayores_45'] = paro['prop_mayores_45'].replace(np.nan, 0.35, regex=True)

# %% [markdown]
# Y finalmente guardamos el dataset, uno por cada elección. En el caso de la de 2011, el formato de los datos fue algo diferente, lo que requirió un cuaderno especial, pero el procedimiento fue de todas formas similar.

# %%
paro.to_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-19-Nov/paro_muni_N19.txt', sep = ',', index = False)
