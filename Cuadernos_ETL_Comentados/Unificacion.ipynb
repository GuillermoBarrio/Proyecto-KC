# %% [markdown]
# # Unificación de datos y creación de los datasets

# %% [markdown]
# En este cuaderno, por fin, llevamos a cabo la uniificación de los datos electorales y sociodemográficos en un solo dataset por cada elección.
#
# Tomaremos como base el df con los datos electorales e iremos añadiendo los del afiliación a la SS, paro y edades y demás. Aprovecharemos para definir columnas que pueden resultar interesantes para llevar a cabo diversas modelizaciones.
#
# Una de las virtudes de los datasets es que no hay una variable objetivo obvia, sino que se pueden elegir en teoría infinitas.
#
# Comenzamos cargando las librerías y el dataset de los resultados electorales, en este caso el de las elecciones de noviembre de 2011.

# %%
import pandas as pd
import numpy as np

# %%
strings = {'Sección' : 'str', 'cod_ccaa' : 'str', 'cod_prov' : 'str', 'cod_mun' : 'str'}

# %%
votos = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-11-Nov/resultados_comp_N11_territ.txt', dtype = strings)

# %%
votos
# Out:
#                      Sección cod_ccaa cod_prov  ... Compromis PACMA Otros
# 0      022011111010400101001       01       04  ...         0     0    10
# 1      022011111010400201001       01       04  ...         0     0     9
# 2      022011111010400301001       01       04  ...         0     0     6
# 3      022011111010400301002       01       04  ...         0     0    18
# 4      022011111010400301003       01       04  ...         0     0     7
# ...                      ...      ...      ...  ...       ...   ...   ...
# 35952  022011111195200108010       19       52  ...         0     3    19
# 35953  022011111195200108011       19       52  ...         0     3    19
# 35954  022011111195200108012       19       52  ...         0     5    30
# 35955  022011111195200108013       19       52  ...         0     2    12
# 35956  022011111195200108014       19       52  ...         0     1     8
#
# [35957 rows x 38 columns]

# %%
votos['Amaiur'].sum()
# Out:
# 333762

# %%
votos.columns
# Out:
# Index(['Sección', 'cod_ccaa', 'cod_prov', 'cod_mun', 'CCAA', 'Provincia',
#        'Municipio', 'Censo_Esc', 'Votos_Total', 'Nulos', 'Votos_Válidos',
#        'Blanco', 'V_Cand', 'PP', 'PSOE', 'Cs', 'UP', 'IU', 'VOX', 'UPyD', 'MP',
#        'CiU', 'ERC', 'JxC', 'CUP', 'DiL', 'PNV', 'Bildu', 'Amaiur', 'CC', 'FA',
#        'TE', 'BNG', 'PRC', 'GBai', 'Compromis', 'PACMA', 'Otros'],
#       dtype='object')

# %%
strings = {'Sección' : 'str', 'cod_ccaa' : 'str', 'cod_prov' : 'str', 'cod_mun' : 'str'}

# %% [markdown]
# Lo primero que hacemos es definir una columna con el código de la sección, 'cod_sec', que son simplemente los 10 últimos dígitos de la columna Sección. Eso nos permitirá hacer los merge de forma más cómoda.

# %%
votos['cod_sec'] = votos['Sección'].str[-10:]

# %%
votos
# Out:
#                      Sección cod_ccaa cod_prov  ... PACMA Otros     cod_sec
# 0      022011111010400101001       01       04  ...     0    10  0400101001
# 1      022011111010400201001       01       04  ...     0     9  0400201001
# 2      022011111010400301001       01       04  ...     0     6  0400301001
# 3      022011111010400301002       01       04  ...     0    18  0400301002
# 4      022011111010400301003       01       04  ...     0     7  0400301003
# ...                      ...      ...      ...  ...   ...   ...         ...
# 35952  022011111195200108010       19       52  ...     3    19  5200108010
# 35953  022011111195200108011       19       52  ...     3    19  5200108011
# 35954  022011111195200108012       19       52  ...     5    30  5200108012
# 35955  022011111195200108013       19       52  ...     2    12  5200108013
# 35956  022011111195200108014       19       52  ...     1     8  5200108014
#
# [35957 rows x 39 columns]

# %% [markdown]
# Ahora cargamos el dataset de edades, que vemos que tiene también la columna del código de secciones.

# %%
strings_edades = {'cod_sec' : 'str'}

# %%
edades = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-11-Nov/2012_df_edades_secciones.csv', dtype = strings_edades)

# %%
edades
# Out:
#           cod_sec  0-4  5-9  10-14  ...  100 y más  Total  Hombres  Mujeres
# 0      0100101001  119  103     65  ...          0   1341      698      643
# 1      0100101002  131  120     89  ...          0   1528      786      742
# 2      0100201001   91   60     81  ...          0   1979     1012      967
# 3      0100201002   64   44     52  ...          0   1702      894      808
# 4      0100201003   46   43     41  ...          0   1042      517      525
# ...           ...  ...  ...    ...  ...        ...    ...      ...      ...
# 35973  5200108010   74   60     84  ...          0   1480      735      745
# 35974  5200108011  148  155    148  ...          0   2107     1057     1050
# 35975  5200108012  143  145    125  ...          0   2532     1307     1225
# 35976  5200108013  108   84     80  ...          0   1762      974      788
# 35977  5200108014   91   86     56  ...          0   1304      626      678
#
# [35978 rows x 25 columns]

# %% [markdown]
# Pasamos a hacer el merge correspondiente de votos y edades a partir del código de la sección.

# %%
votos_edades = pd.merge(votos, edades, how="left", on=['cod_sec'])

# %%
votos_edades
# Out:
#                      Sección cod_ccaa cod_prov  ...   Total Hombres Mujeres
# 0      022011111010400101001       01       04  ...  1465.0   765.0   700.0
# 1      022011111010400201001       01       04  ...  1360.0   699.0   661.0
# 2      022011111010400301001       01       04  ...   966.0   459.0   507.0
# 3      022011111010400301002       01       04  ...  1579.0   789.0   790.0
# 4      022011111010400301003       01       04  ...  1789.0   871.0   918.0
# ...                      ...      ...      ...  ...     ...     ...     ...
# 35952  022011111195200108010       19       52  ...  1480.0   735.0   745.0
# 35953  022011111195200108011       19       52  ...  2107.0  1057.0  1050.0
# 35954  022011111195200108012       19       52  ...  2532.0  1307.0  1225.0
# 35955  022011111195200108013       19       52  ...  1762.0   974.0   788.0
# 35956  022011111195200108014       19       52  ...  1304.0   626.0   678.0
#
# [35957 rows x 63 columns]

# %% [markdown]
# Ahora vamos con los datos de la afiiación a la Seguridad Social. Recordamos que teníamos los datos solo por municipios.

# %%
strings_seg_sol = {'cod_mun' : 'str'}

# %%
seg_sol = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-11-Nov/seg_sol_muni_N11.txt', dtype = strings_seg_sol)

# %%
seg_sol
# Out:
#            PROVINCIA cod_mun  ... Total_afiliados  prop_autonomos
# 0     01 ARABA/ÁLAVA   01001  ...             774        0.244186
# 1     01 ARABA/ÁLAVA   01002  ...            4476        0.139857
# 2     01 ARABA/ÁLAVA   01003  ...             234        0.294872
# 3     01 ARABA/ÁLAVA   01004  ...             399        0.255639
# 4     01 ARABA/ÁLAVA   01006  ...             137        0.153285
# ...              ...     ...  ...             ...             ...
# 8091     50 ZARAGOZA   50298  ...            3589        0.264698
# 8092     50 ZARAGOZA   50901  ...              30        0.566667
# 8093     50 ZARAGOZA   50903  ...             644        0.358696
# 8094        51 CEUTA   51001  ...           19959        0.148605
# 8095      52 MELILLA   52001  ...           19893        0.161816
#
# [8096 rows x 5 columns]

# %%
seg_sol.columns
# Out:
# Index(['PROVINCIA', 'cod_mun', 'Municipio', 'Total_afiliados',
#        'prop_autonomos'],
#       dtype='object')

# %% [markdown]
# Para hacer el merge no nos hacen falta los datos de las provincias o municpios, solo el código de estos últimos para hacer el merge.

# %%
seg_sol_simp = seg_sol[['cod_mun', 'Total_afiliados',
       'prop_autonomos']]

# %%
seg_sol_simp
# Out:
#      cod_mun  Total_afiliados  prop_autonomos
# 0      01001              774        0.244186
# 1      01002             4476        0.139857
# 2      01003              234        0.294872
# 3      01004              399        0.255639
# 4      01006              137        0.153285
# ...      ...              ...             ...
# 8091   50298             3589        0.264698
# 8092   50901               30        0.566667
# 8093   50903              644        0.358696
# 8094   51001            19959        0.148605
# 8095   52001            19893        0.161816
#
# [8096 rows x 3 columns]

# %% [markdown]
# Hacemos el merge entre el dataset de votos y edades y este de la afiliación, mediante el código del municipio.
#
# Como se ve, vamos añadiendo datasets de forma progresiva.

# %%
votos_edades_segsol = pd.merge(votos_edades, seg_sol_simp, how="left", on=['cod_mun'])

# %%
votos_edades_segsol
# Out:
#                      Sección cod_ccaa  ... Total_afiliados prop_autonomos
# 0      022011111010400101001       01  ...           281.0       0.241993
# 1      022011111010400201001       01  ...           387.0       0.224806
# 2      022011111010400301001       01  ...          7161.0       0.357213
# 3      022011111010400301002       01  ...          7161.0       0.357213
# 4      022011111010400301003       01  ...          7161.0       0.357213
# ...                      ...      ...  ...             ...            ...
# 36058  022011111195200108010       19  ...         19893.0       0.161816
# 36059  022011111195200108011       19  ...         19893.0       0.161816
# 36060  022011111195200108012       19  ...         19893.0       0.161816
# 36061  022011111195200108013       19  ...         19893.0       0.161816
# 36062  022011111195200108014       19  ...         19893.0       0.161816
#
# [36063 rows x 65 columns]

# %% [markdown]
# Ahora vamos con los datos del paro, que también solo tienen datos del paro por municipios.

# %%
strings_paro = {'cod_mun' : 'str'}

# %%
paro = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-11-Nov/paro_muni_N11.txt', dtype = strings_seg_sol)

# %%
paro
# Out:
#       Código mes   cod_ccaa  ... prop_hombres  prop_mayores_45
# 0          201111         1  ...     0.553763         0.500000
# 1          201111         1  ...     0.427313         0.594714
# 2          201111         1  ...     0.525255         0.369013
# 3          201111         1  ...     0.516129         0.306452
# 4          201111         1  ...     0.459016         0.524590
# ...           ...       ...  ...          ...              ...
# 8112       201111        17  ...     0.526316         0.473684
# 8113       201111        17  ...     0.500000         0.350000
# 8114       201111        17  ...     0.800000         0.400000
# 8115       201111        18  ...     0.420449         0.298344
# 8116       201111        19  ...     0.407173         0.319176
#
# [8117 rows x 10 columns]

# %%
paro.columns
# Out:
# Index(['Código mes ', 'cod_ccaa', 'CCAA', 'cod_prov', 'Provincia', 'cod_mun',
#        'Municipio', 'total Dtes Empleo', 'prop_hombres', 'prop_mayores_45'],
#       dtype='object')

# %% [markdown]
# Nos quedamos con los datos del paro necesarios y el código del municipio.

# %%
paro_simp = paro[['cod_mun', 'total Dtes Empleo', 'prop_hombres', 'prop_mayores_45']]

# %%
paro_simp
# Out:
#      cod_mun  total Dtes Empleo  prop_hombres  prop_mayores_45
# 0      04001                186      0.553763         0.500000
# 1      04002                227      0.427313         0.594714
# 2      04003               3821      0.525255         0.369013
# 3      04004                 62      0.516129         0.306452
# 4      04005                122      0.459016         0.524590
# ...      ...                ...           ...              ...
# 8112   26180                 19      0.526316         0.473684
# 8113   26181                  0      0.500000         0.350000
# 8114   26183                  5      0.800000         0.400000
# 8115   51001              13947      0.420449         0.298344
# 8116   52001              14080      0.407173         0.319176
#
# [8117 rows x 4 columns]

# %% [markdown]
# Hacemos el merge igual que en el caso anterior

# %%
votos_edades_segsol_paro = pd.merge(votos_edades_segsol, paro_simp, how="left", on=['cod_mun'])

# %%
votos_edades_segsol_paro
# Out:
#                      Sección cod_ccaa  ... prop_hombres prop_mayores_45
# 0      022011111010400101001       01  ...     0.553763        0.500000
# 1      022011111010400201001       01  ...     0.427313        0.594714
# 2      022011111010400301001       01  ...     0.525255        0.369013
# 3      022011111010400301002       01  ...     0.525255        0.369013
# 4      022011111010400301003       01  ...     0.525255        0.369013
# ...                      ...      ...  ...          ...             ...
# 36058  022011111195200108010       19  ...     0.407173        0.319176
# 36059  022011111195200108011       19  ...     0.407173        0.319176
# 36060  022011111195200108012       19  ...     0.407173        0.319176
# 36061  022011111195200108013       19  ...     0.407173        0.319176
# 36062  022011111195200108014       19  ...     0.407173        0.319176
#
# [36063 rows x 68 columns]

# %% [markdown]
# Pasamos a la renta de las secciones, que cargamos sin novedad. Aquí los datos son por secciones.

# %%
strings_ren_sec = {'cod_sec' : 'str'}

# %%
ren_sec = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/rentas_secciones_15_17.txt', dtype = strings_ren_sec)

# %%
ren_sec
# Out:
#                                       Territorio  ...  RNM hog 2015
# 0      0100101001 Alegría-Dulantzi sección 01001  ...  26938.114416
# 1      0100101002 Alegría-Dulantzi sección 01002  ...  26938.114416
# 2               0100201001 Amurrio sección 01001  ...  34421.000000
# 3               0100201002 Amurrio sección 01002  ...  34421.000000
# 4               0100201003 Amurrio sección 01003  ...  34421.000000
# ...                                          ...  ...           ...
# 36444           5200108011 Melilla sección 08011  ...  62632.000000
# 36445           5200108012 Melilla sección 08012  ...  50839.000000
# 36446           5200108013 Melilla sección 08013  ...  36729.000000
# 36447           5200108014 Melilla sección 08014  ...  31384.000000
# 36448           5200108015 Melilla sección 08015  ...  38863.000000
#
# [36449 rows x 6 columns]

# %%
ren_sec.columns
# Out:
# Index(['Territorio', 'cod_sec', 'RNM per 2017', 'RNM per 2015', 'RNM hog 2017',
#        'RNM hog 2015'],
#       dtype='object')

# %% [markdown]
# Nos quedamos con los datos de las rentas, y el código de sección...

# %%
ren_sec_simp = ren_sec[['cod_sec', 'RNM per 2017', 'RNM per 2015', 'RNM hog 2017',
       'RNM hog 2015']]

# %%
ren_sec_simp
# Out:
#           cod_sec  RNM per 2017  RNM per 2015  RNM hog 2017  RNM hog 2015
# 0      0100101001  11234.267197  10618.182737  28322.021999  26938.114416
# 1      0100101002  11234.267197  10618.182737  28322.021999  26938.114416
# 2      0100201001  13862.000000  13800.000000  34411.000000  34421.000000
# 3      0100201002  13862.000000  13800.000000  34411.000000  34421.000000
# 4      0100201003  13862.000000  13800.000000  34411.000000  34421.000000
# ...           ...           ...           ...           ...           ...
# 36444  5200108011  16433.000000  15847.000000  66352.000000  62632.000000
# 36445  5200108012  17350.000000  16792.000000  50730.000000  50839.000000
# 36446  5200108013  12553.000000  11823.000000  37816.000000  36729.000000
# 36447  5200108014   8906.000000   8937.000000  29898.000000  31384.000000
# 36448  5200108015  12314.000000  11813.000000  39713.000000  38863.000000
#
# [36449 rows x 5 columns]

# %% [markdown]
# ... y hacemos simplemente otro merge.

# %%
votos_edades_segsol_paro_rensec = pd.merge(votos_edades_segsol_paro, ren_sec_simp, how="left", on=['cod_sec'])

# %%
votos_edades_segsol_paro_rensec
# Out:
#                      Sección cod_ccaa  ... RNM hog 2017 RNM hog 2015
# 0      022011111010400101001       01  ...      20172.0      19546.0
# 1      022011111010400201001       01  ...      17841.0      17115.0
# 2      022011111010400301001       01  ...      26498.0      24688.0
# 3      022011111010400301002       01  ...      25677.0      23400.0
# 4      022011111010400301003       01  ...      22051.0      19687.0
# ...                      ...      ...  ...          ...          ...
# 36058  022011111195200108010       19  ...      45725.0      46108.0
# 36059  022011111195200108011       19  ...      66352.0      62632.0
# 36060  022011111195200108012       19  ...      50730.0      50839.0
# 36061  022011111195200108013       19  ...      37816.0      36729.0
# 36062  022011111195200108014       19  ...      29898.0      31384.0
#
# [36063 rows x 72 columns]

# %% [markdown]
# Finalmente cargamos el dataset de la distribución de rentas por conceptos; también tiene los datos por secciones.

# %%
strings_dist_ren_sec = {'cod_sec' : 'str'}

# %%
dist_ren_sec = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Dist_renta_hogares_15_18.txt', dtype = strings_dist_ren_sec)

# %%
dist_ren_sec
# Out:
#                                               Territorio  ...  Desem 2015
# 0      1190301001 San Martín del Tesorillo sección 01001  ...  347.217589
# 1      1190301002 San Martín del Tesorillo sección 01002  ...  347.217589
# 2             1490101001 Fuente Carreteros sección 01001  ...  347.217589
# 3                1490201001 Guijarrosa, La sección 01001  ...  347.217589
# 4                        1807701001 Fornes sección 01001  ...  347.217589
# ...                                                  ...  ...         ...
# 34283                   5200108011 Melilla sección 08011  ...  166.000000
# 34284                   5200108012 Melilla sección 08012  ...  177.000000
# 34285                   5200108013 Melilla sección 08013  ...  252.000000
# 34286                   5200108014 Melilla sección 08014  ...  284.000000
# 34287                   5200108015 Melilla sección 08015  ...  218.000000
#
# [34288 rows x 8 columns]

# %%
dist_ren_sec.columns
# Out:
# Index(['Territorio', 'cod_sec', 'Sal 2018', 'Sal 2015', 'Pen 2018', 'Pen 2015',
#        'Desem 2018', 'Desem 2015'],
#       dtype='object')

# %% [markdown]
# Tras quedarnos con las columnas realmente útiles, y el código de sección...

# %%
dist_ren_sec_simp = dist_ren_sec[[ 'cod_sec', 'Sal 2018', 'Sal 2015', 'Pen 2018', 'Pen 2015',
       'Desem 2018', 'Desem 2015']]

# %%
dist_ren_sec_simp
# Out:
#           cod_sec  Sal 2018      Sal 2015  ...     Pen 2015  Desem 2018  Desem 2015
# 0      1190301001    4903.0   6845.948425  ...  2985.302533       321.0  347.217589
# 1      1190301002    4396.0   6845.948425  ...  2985.302533       318.0  347.217589
# 2      1490101001    3669.0   6845.948425  ...  2985.302533       846.0  347.217589
# 3      1490201001    4288.0   6845.948425  ...  2985.302533       846.0  347.217589
# 4      1807701001    4170.0   6845.948425  ...  2985.302533       813.0  347.217589
# ...           ...       ...           ...  ...          ...         ...         ...
# 34283  5200108011   11378.0  11119.000000  ...  1274.000000       167.0  166.000000
# 34284  5200108012   13272.0  13038.000000  ...  2445.000000       169.0  177.000000
# 34285  5200108013   10102.0   9640.000000  ...  1615.000000       234.0  252.000000
# 34286  5200108014    5923.0   6061.000000  ...  2136.000000       244.0  284.000000
# 34287  5200108015   10651.0   9570.000000  ...  1638.000000       203.0  218.000000
#
# [34288 rows x 7 columns]

# %% [markdown]
# ...ejecutamos el merge.

# %%
votos_edades_segsol_paro_rensec_distrensec = pd.merge(votos_edades_segsol_paro_rensec, dist_ren_sec_simp, how="left", on=['cod_sec'])

# %%
votos_edades_segsol_paro_rensec_distrensec
# Out:
#                      Sección cod_ccaa  ... Desem 2018 Desem 2015
# 0      022011111010400101001       01  ...      403.0      471.0
# 1      022011111010400201001       01  ...      568.0      620.0
# 2      022011111010400301001       01  ...      337.0      333.0
# 3      022011111010400301002       01  ...      343.0      464.0
# 4      022011111010400301003       01  ...      416.0      476.0
# ...                      ...      ...  ...        ...        ...
# 36058  022011111195200108010       19  ...      165.0      155.0
# 36059  022011111195200108011       19  ...      167.0      166.0
# 36060  022011111195200108012       19  ...      169.0      177.0
# 36061  022011111195200108013       19  ...      234.0      252.0
# 36062  022011111195200108014       19  ...      244.0      284.0
#
# [36063 rows x 78 columns]

# %% [markdown]
# Ahora ya hemos unificado las bases de datos, y hacemos una primera grabación.

# %%
votos_edades_segsol_paro_rensec_distrensec.to_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-11-Nov/gen_N11_unif_cols_prov.txt', sep = ',', index = False)

# %% [markdown]
# Pero no hemos terminado, porque podemos comenzar a añadir columnas en función de las existentes, que nos resulten útiles. Una evidente es la participación electoral.
#
# Pandas por defecto va colocando las nuevas columnas a la derecha del todo; posteriormente ya las colocaremos como nos venga mejor.

# %%
votos_edades_segsol_paro_rensec_distrensec['Participación'] = votos_edades_segsol_paro_rensec_distrensec['Votos_Total'] / votos_edades_segsol_paro_rensec_distrensec['Censo_Esc']

# %%
votos_edades_segsol_paro_rensec_distrensec
# Out:
#                      Sección cod_ccaa  ... Desem 2015 Participación
# 0      022011111010400101001       01  ...      471.0      0.781387
# 1      022011111010400201001       01  ...      620.0      0.777487
# 2      022011111010400301001       01  ...      333.0      0.777299
# 3      022011111010400301002       01  ...      464.0      0.724763
# 4      022011111010400301003       01  ...      476.0      0.725780
# ...                      ...      ...  ...        ...           ...
# 36058  022011111195200108010       19  ...      155.0      0.641556
# 36059  022011111195200108011       19  ...      166.0      0.590247
# 36060  022011111195200108012       19  ...      177.0      0.631270
# 36061  022011111195200108013       19  ...      252.0      0.545844
# 36062  022011111195200108014       19  ...      284.0      0.606960
#
# [36063 rows x 79 columns]

# %%
votos_edades_segsol_paro_rensec_distrensec.columns
# Out:
# Index(['Sección', 'cod_ccaa', 'cod_prov', 'cod_mun', 'CCAA', 'Provincia',
#        'Municipio', 'Censo_Esc', 'Votos_Total', 'Nulos', 'Votos_Válidos',
#        'Blanco', 'V_Cand', 'PP', 'PSOE', 'Cs', 'UP', 'IU', 'VOX', 'UPyD', 'MP',
#        'CiU', 'ERC', 'JxC', 'CUP', 'DiL', 'PNV', 'Bildu', 'Amaiur', 'CC', 'FA',
#        'TE', 'BNG', 'PRC', 'GBai', 'Compromis', 'PACMA', 'Otros', 'cod_sec',
#        '0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
#        '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79',
#        '80-84', '85-89', '90-94', '95-99', '100 y más', 'Total', 'Hombres',
#        'Mujeres', 'Total_afiliados', 'prop_autonomos', 'total Dtes Empleo',
#        'prop_hombres', 'prop_mayores_45', 'RNM per 2017', 'RNM per 2015',
#        'RNM hog 2017', 'RNM hog 2015', 'Sal 2018', 'Sal 2015', 'Pen 2018',
#        'Pen 2015', 'Desem 2018', 'Desem 2015', 'Participación'],
#       dtype='object')

# %% [markdown]
# Ahora vamos a definir una serie de columnas que nos digan qué partido ganó en cada sección, y quién quedó segundo, tercero, cuarto y quinto.
#
# Ello lleva varios pasos, comenzando con la creación de un diccionario que almacene los resultados electorales en formato partido : votos.

# %%
partidos = ['PP', 'PSOE', 'Cs', 'UP', 'IU', 'VOX', 'UPyD', 'MP',
       'CiU', 'ERC', 'JxC', 'CUP', 'DiL', 'PNV', 'Bildu', 'Amaiur', 'CC', 'FA',
       'TE', 'BNG', 'PRC', 'GBai', 'Compromis', 'PACMA', 'Otros']

# %%
votos_edades_segsol_paro_rensec_distrensec['dict_res'] = ''

# %%
for ind in range(len(votos_edades_segsol_paro_rensec_distrensec['Sección'])):
  votos_edades_segsol_paro_rensec_distrensec['dict_res'][ind] = {p : votos_edades_segsol_paro_rensec_distrensec[p][ind] for p in partidos }
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
votos_edades_segsol_paro_rensec_distrensec
# Out:
#                      Sección  ...                                           dict_res
# 0      022011111010400101001  ...  {'PP': 434, 'PSOE': 373, 'Cs': 0, 'UP': 0, 'IU...
# 1      022011111010400201001  ...  {'PP': 361, 'PSOE': 454, 'Cs': 0, 'UP': 0, 'IU...
# 2      022011111010400301001  ...  {'PP': 364, 'PSOE': 129, 'Cs': 0, 'UP': 0, 'IU...
# 3      022011111010400301002  ...  {'PP': 547, 'PSOE': 223, 'Cs': 0, 'UP': 0, 'IU...
# 4      022011111010400301003  ...  {'PP': 598, 'PSOE': 195, 'Cs': 0, 'UP': 0, 'IU...
# ...                      ...  ...                                                ...
# 36058  022011111195200108010  ...  {'PP': 541, 'PSOE': 146, 'Cs': 0, 'UP': 0, 'IU...
# 36059  022011111195200108011  ...  {'PP': 535, 'PSOE': 187, 'Cs': 0, 'UP': 0, 'IU...
# 36060  022011111195200108012  ...  {'PP': 843, 'PSOE': 245, 'Cs': 0, 'UP': 0, 'IU...
# 36061  022011111195200108013  ...  {'PP': 415, 'PSOE': 167, 'Cs': 0, 'UP': 0, 'IU...
# 36062  022011111195200108014  ...  {'PP': 430, 'PSOE': 127, 'Cs': 0, 'UP': 0, 'IU...
#
# [36063 rows x 80 columns]

# %% [markdown]
# Vemos un ejemplo tomado al azar.

# %%
a = votos_edades_segsol_paro_rensec_distrensec['dict_res'][852]

# %%
a
# Out:
# {'Amaiur': 0,
#  'BNG': 0,
#  'Bildu': 0,
#  'CC': 0,
#  'CUP': 0,
#  'CiU': 0,
#  'Compromis': 0,
#  'Cs': 0,
#  'DiL': 0,
#  'ERC': 0,
#  'FA': 0,
#  'GBai': 0,
#  'IU': 42,
#  'JxC': 0,
#  'MP': 0,
#  'Otros': 25,
#  'PACMA': 3,
#  'PNV': 0,
#  'PP': 140,
#  'PRC': 0,
#  'PSOE': 174,
#  'TE': 0,
#  'UP': 0,
#  'UPyD': 20,
#  'VOX': 0}

# %% [markdown]
# Ahora lo tenemos que ordenar por los votos de manera decreciente, almecenando los datos en un array de tuplas. Este sería un ejemplo en base al diccionario anterior

# %%
b = sorted(a.items(), key=lambda item: item[1], reverse = True)

# %%
b
# Out:
# [('PSOE', 174),
#  ('PP', 140),
#  ('IU', 42),
#  ('Otros', 25),
#  ('UPyD', 20),
#  ('PACMA', 3),
#  ('Cs', 0),
#  ('UP', 0),
#  ('VOX', 0),
#  ('MP', 0),
#  ('CiU', 0),
#  ('ERC', 0),
#  ('JxC', 0),
#  ('CUP', 0),
#  ('DiL', 0),
#  ('PNV', 0),
#  ('Bildu', 0),
#  ('Amaiur', 0),
#  ('CC', 0),
#  ('FA', 0),
#  ('TE', 0),
#  ('BNG', 0),
#  ('PRC', 0),
#  ('GBai', 0),
#  ('Compromis', 0)]

# %%
b[0]
# Out:
# ('PSOE', 174)

# %%
b[0][0]
# Out:
# 'PSOE'

# %% [markdown]
# Ahora iteramos por los diccionarios de cada registro, y los depositamos en una columna, en este caso la de 'dict_res_ord'.

# %%
votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'] = ''

# %%
for ind in range(len(votos_edades_segsol_paro_rensec_distrensec['Sección'])):

  a = votos_edades_segsol_paro_rensec_distrensec['dict_res'][ind]
  votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'][ind] = sorted(a.items(), key=lambda item: item[1], reverse = True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# Vemos el ejemplo tomado ya del propio dataset. Parece correcto.

# %%
votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'][852]
# Out:
# [('PSOE', 174),
#  ('PP', 140),
#  ('IU', 42),
#  ('Otros', 25),
#  ('UPyD', 20),
#  ('PACMA', 3),
#  ('Cs', 0),
#  ('UP', 0),
#  ('VOX', 0),
#  ('MP', 0),
#  ('CiU', 0),
#  ('ERC', 0),
#  ('JxC', 0),
#  ('CUP', 0),
#  ('DiL', 0),
#  ('PNV', 0),
#  ('Bildu', 0),
#  ('Amaiur', 0),
#  ('CC', 0),
#  ('FA', 0),
#  ('TE', 0),
#  ('BNG', 0),
#  ('PRC', 0),
#  ('GBai', 0),
#  ('Compromis', 0)]

# %% [markdown]
# Identificamos al ganador con el doble índice [0][0].
#
# Análogamente, veremos que el segundo partido tendrá un doble índice [1][0], y así sucesivamente.

# %%
votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'][852][0][0]
# Out:
# 'PSOE'

# %% [markdown]
# Tenemos que crear las columnas que almacenarán los puestos de cada sección.

# %%
votos_edades_segsol_paro_rensec_distrensec['Ganador'] = ''
votos_edades_segsol_paro_rensec_distrensec['Segundo'] = ''
votos_edades_segsol_paro_rensec_distrensec['Tercero'] = ''
votos_edades_segsol_paro_rensec_distrensec['Cuarto'] = ''
votos_edades_segsol_paro_rensec_distrensec['Quinto'] = ''

# %% [markdown]
# Ahora metemos en la columna Ganador al partido ganador de la sección. Lógicamente, en noviembre de 2011 el PP ganó en la gran mayoría de ellas.

# %%
votos_edades_segsol_paro_rensec_distrensec['Ganador'] = votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'].apply(lambda x : x[0][0])

# %%
votos_edades_segsol_paro_rensec_distrensec['Ganador'].value_counts()
# Out:
# PP        25459
# PSOE       6731
# CiU        2668
# PNV         594
# Amaiur      532
# IU           27
# CC           17
# Otros        15
# GBai          7
# ERC           5
# BNG           5
# PACMA         1
# PRC           1
# UPyD          1
# Name: Ganador, dtype: int64

# %% [markdown]
# Ahora vamos con el que quedó segundo, en este caso el PSOE.

# %%
votos_edades_segsol_paro_rensec_distrensec['Segundo'] = votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'].apply(lambda x : x[1][0])

# %%
votos_edades_segsol_paro_rensec_distrensec['Segundo'].value_counts()
# Out:
# PSOE      26312
# PP         6797
# PNV         635
# CiU         631
# Amaiur      453
# ERC         285
# CC          262
# IU          181
# Otros       160
# UPyD        140
# GBai        113
# BNG          51
# PRC          40
# PACMA         3
# Name: Segundo, dtype: int64

# %% [markdown]
# Y finalmente rellenamos los puestos tercero, cuarto y quinto.

# %%
votos_edades_segsol_paro_rensec_distrensec['Tercero'] = votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'].apply(lambda x : x[2][0])

# %%
votos_edades_segsol_paro_rensec_distrensec['Cuarto'] = votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'].apply(lambda x : x[3][0])

# %%
votos_edades_segsol_paro_rensec_distrensec['Quinto'] = votos_edades_segsol_paro_rensec_distrensec['dict_res_ord'].apply(lambda x : x[4][0])

# %%
votos_edades_segsol_paro_rensec_distrensec['Quinto'].value_counts()
# Out:
# Otros     19774
# UPyD       6584
# IU         5544
# ERC        1440
# PACMA       987
# Cs          973
# UP          369
# PP          138
# PSOE         58
# CC           54
# CiU          47
# Amaiur       47
# GBai         40
# PRC           6
# PNV           2
# Name: Quinto, dtype: int64

# %% [markdown]
# Las columnas de los puestos pandas las coloca a la derecha del todo por defecto.

# %%
votos_edades_segsol_paro_rensec_distrensec
# Out:
#                      Sección cod_ccaa cod_prov  ... Tercero Cuarto Quinto
# 0      022011111010400101001       01       04  ...      IU   UPyD  Otros
# 1      022011111010400201001       01       04  ...      IU   UPyD  Otros
# 2      022011111010400301001       01       04  ...    UPyD     IU  Otros
# 3      022011111010400301002       01       04  ...    UPyD  Otros     IU
# 4      022011111010400301003       01       04  ...      IU   UPyD  Otros
# ...                      ...      ...      ...  ...     ...    ...    ...
# 36058  022011111195200108010       19       52  ...    UPyD  Otros  PACMA
# 36059  022011111195200108011       19       52  ...    UPyD  Otros  PACMA
# 36060  022011111195200108012       19       52  ...    UPyD  Otros  PACMA
# 36061  022011111195200108013       19       52  ...    UPyD  Otros  PACMA
# 36062  022011111195200108014       19       52  ...    UPyD  Otros  PACMA
#
# [36063 rows x 86 columns]

# %% [markdown]
# Estas son las columnas que llevamos, 86.

# %%
a = list(votos_edades_segsol_paro_rensec_distrensec.columns)
a
# Out:
# ['Sección',
#  'cod_ccaa',
#  'cod_prov',
#  'cod_mun',
#  'CCAA',
#  'Provincia',
#  'Municipio',
#  'Censo_Esc',
#  'Votos_Total',
#  'Nulos',
#  'Votos_Válidos',
#  'Blanco',
#  'V_Cand',
#  'PP',
#  'PSOE',
#  'Cs',
#  'UP',
#  'IU',
#  'VOX',
#  'UPyD',
#  'MP',
#  'CiU',
#  'ERC',
#  'JxC',
#  'CUP',
#  'DiL',
#  'PNV',
#  'Bildu',
#  'Amaiur',
#  'CC',
#  'FA',
#  'TE',
#  'BNG',
#  'PRC',
#  'GBai',
#  'Compromis',
#  'PACMA',
#  'Otros',
#  'cod_sec',
#  '0-4',
#  '5-9',
#  '10-14',
#  '15-19',
#  '20-24',
#  '25-29',
#  '30-34',
#  '35-39',
#  '40-44',
#  '45-49',
#  '50-54',
#  '55-59',
#  '60-64',
#  '65-69',
#  '70-74',
#  '75-79',
#  '80-84',
#  '85-89',
#  '90-94',
#  '95-99',
#  '100 y más',
#  'Total',
#  'Hombres',
#  'Mujeres',
#  'Total_afiliados',
#  'prop_autonomos',
#  'total Dtes Empleo',
#  'prop_hombres',
#  'prop_mayores_45',
#  'RNM per 2017',
#  'RNM per 2015',
#  'RNM hog 2017',
#  'RNM hog 2015',
#  'Sal 2018',
#  'Sal 2015',
#  'Pen 2018',
#  'Pen 2015',
#  'Desem 2018',
#  'Desem 2015',
#  'Participación',
#  'dict_res',
#  'dict_res_ord',
#  'Ganador',
#  'Segundo',
#  'Tercero',
#  'Cuarto',
#  'Quinto']

# %% [markdown]
# Otra columna interesante puede ser la suma de los mayores de edad, que podemos definir como los mayores de 64 años, y así la definimos y la calculamos.

# %%
votos_edades_segsol_paro_rensec_distrensec['mayores_65_años'] = 0

# %%
mayores = ['65-69', '70-74', '75-79','80-84', '85-89', '90-94', '95-99', '100 y más']

# %%
votos_edades_segsol_paro_rensec_distrensec['mayores_65_años'] = votos_edades_segsol_paro_rensec_distrensec[mayores].sum(axis=1)

# %%
votos_edades_segsol_paro_rensec_distrensec['mayores_65_años']
# Out:
# 0        359.0
# 1        336.0
# 2        143.0
# 3        153.0
# 4        200.0
#          ...
# 36058    203.0
# 36059    158.0
# 36060    319.0
# 36061    152.0
# 36062    155.0
# Name: mayores_65_años, Length: 36063, dtype: float64

# %% [markdown]
# Podemos hacer lo mismo con los menores de edad; es cierto que éstos no votan, pero puede ser un factor importante en los que só lo hacen.

# %%
votos_edades_segsol_paro_rensec_distrensec['menores_19_años'] = 0

# %%
menores = ['0-4','5-9', '10-14','15-19']

# %%
votos_edades_segsol_paro_rensec_distrensec['menores_19_años'] = votos_edades_segsol_paro_rensec_distrensec[menores].sum(axis=1)

# %%
votos_edades_segsol_paro_rensec_distrensec['menores_19_años']
# Out:
# 0        228.0
# 1        192.0
# 2        206.0
# 3        374.0
# 4        437.0
#          ...
# 36058    298.0
# 36059    620.0
# 36060    531.0
# 36061    353.0
# 36062    294.0
# Name: menores_19_años, Length: 36063, dtype: float64

# %% [markdown]
# Por otro lado, podemos definir una columna con una especie de tasa de paro, que podemos definir como los demandantes de empleo entre la suma de los demandantes de empleo y los afiliados a la Seguridad Social.
#
# En general, debemos dar una cierta prioridad a los datos que sean proporciones y datos absolutos, pues los primeros se pueden comparar independientemente del tamaño de la población.

# %%
votos_edades_segsol_paro_rensec_distrensec['Desempleo'] = votos_edades_segsol_paro_rensec_distrensec['total Dtes Empleo'] / (votos_edades_segsol_paro_rensec_distrensec['total Dtes Empleo'] + votos_edades_segsol_paro_rensec_distrensec['Total_afiliados'] )

# %%
votos_edades_segsol_paro_rensec_distrensec
# Out:
#                      Sección cod_ccaa  ... menores_19_años Desempleo
# 0      022011111010400101001       01  ...           228.0  0.398287
# 1      022011111010400201001       01  ...           192.0  0.369707
# 2      022011111010400301001       01  ...           206.0  0.347933
# 3      022011111010400301002       01  ...           374.0  0.347933
# 4      022011111010400301003       01  ...           437.0  0.347933
# ...                      ...      ...  ...             ...       ...
# 36058  022011111195200108010       19  ...           298.0  0.414447
# 36059  022011111195200108011       19  ...           620.0  0.414447
# 36060  022011111195200108012       19  ...           531.0  0.414447
# 36061  022011111195200108013       19  ...           353.0  0.414447
# 36062  022011111195200108014       19  ...           294.0  0.414447
#
# [36063 rows x 89 columns]

# %%
votos_edades_segsol_paro_rensec_distrensec['Desempleo'].describe()
# Out:
# count    36002.000000
# mean         0.276865
# std          0.119931
# min          0.000000
# 25%          0.190700
# 50%          0.265596
# 75%          0.352664
# max          0.970017
# Name: Desempleo, dtype: float64

# %% [markdown]
# En este momento hacemos una especie parada y fonda, guardando el dataset una vez más, y volviéndolo a cargar.

# %%
votos_edades_segsol_paro_rensec_distrensec.to_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-11-Nov/gen_N11_unif_cols_prov.txt', sep = ',', index = False)

# %%
cols_str = {'cod_ccaa' : 'str', 'cod_prov' : 'str', 'cod_mun' : 'str', 'cod_sec' : 'str', 'cod_grupo' : 'str'}

# %%
gen_xx_cols = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-11-Nov/gen_N11_unif_cols_prov.txt', dtype = cols_str)

# %%
gen_xx_cols.head()
# Out:
#                  Sección cod_ccaa  ... menores_19_años Desempleo
# 0  022011111010400101001       01  ...           228.0  0.398287
# 1  022011111010400201001       01  ...           192.0  0.369707
# 2  022011111010400301001       01  ...           206.0  0.347933
# 3  022011111010400301002       01  ...           374.0  0.347933
# 4  022011111010400301003       01  ...           437.0  0.347933
#
# [5 rows x 89 columns]

# %% [markdown]
# Podemos seguir optimizando las columnas, cambiando los datos absolutos por proporciones, como hemos mencionado anteriormente, en este caso con los mayores y menores de edad.

# %%
gen_xx_cols['mayores_65_años'] = gen_xx_cols['mayores_65_años'] / gen_xx_cols['Total']

# %%
gen_xx_cols['menores_19_años'] = gen_xx_cols['menores_19_años'] / gen_xx_cols['Total']

# %%
gen_xx_cols.head()
# Out:
#                  Sección cod_ccaa  ... menores_19_años Desempleo
# 0  022011111010400101001       01  ...        0.155631  0.398287
# 1  022011111010400201001       01  ...        0.141176  0.369707
# 2  022011111010400301001       01  ...        0.213251  0.347933
# 3  022011111010400301002       01  ...        0.236859  0.347933
# 4  022011111010400301003       01  ...        0.244271  0.347933
#
# [5 rows x 89 columns]

# %% [markdown]
# Ahora debemos definir el porcentaje de voto de cada partido como se hace en realidad: votos a un partido entre el total de votos válidos. Almecenamos esta proporción en columnas paracada partido, tomando los más importantes.

# %%
gen_xx_cols['% PP'] = gen_xx_cols['PP'] / gen_xx_cols['Votos_Válidos']

# %%
gen_xx_cols['% PSOE'] = gen_xx_cols['PSOE'] / gen_xx_cols['Votos_Válidos']

# %%
gen_xx_cols['% UP'] = gen_xx_cols['UP'] / gen_xx_cols['Votos_Válidos']

# %%
gen_xx_cols['% Vox'] = gen_xx_cols['VOX'] / gen_xx_cols['Votos_Válidos']

# %%
gen_xx_cols['% Cs'] = gen_xx_cols['Cs'] / gen_xx_cols['Votos_Válidos']

# %%
gen_xx_cols['% IU'] = gen_xx_cols['IU'] / gen_xx_cols['Votos_Válidos']

# %%
gen_xx_cols.head()
# Out:
#                  Sección cod_ccaa cod_prov cod_mun  ... % UP % Vox % Cs      % IU
# 0  022011111010400101001       01       04   04001  ...  0.0   0.0  0.0  0.038462
# 1  022011111010400201001       01       04   04002  ...  0.0   0.0  0.0  0.045249
# 2  022011111010400301001       01       04   04003  ...  0.0   0.0  0.0  0.024345
# 3  022011111010400301002       01       04   04003  ...  0.0   0.0  0.0  0.019208
# 4  022011111010400301003       01       04   04003  ...  0.0   0.0  0.0  0.040138
#
# [5 rows x 95 columns]

# %% [markdown]
# Ahora comenzamos a cambiar de nombres algunas columnas para hacerlas más reconocibles e interpretables.

# %%
gen_xx_cols.rename(columns = {'Total_afiliados' : 'Afiliados SS Minicipio'})
# Out:
#                      Sección cod_ccaa cod_prov  ... % Vox % Cs      % IU
# 0      022011111010400101001       01       04  ...   0.0  0.0  0.038462
# 1      022011111010400201001       01       04  ...   0.0  0.0  0.045249
# 2      022011111010400301001       01       04  ...   0.0  0.0  0.024345
# 3      022011111010400301002       01       04  ...   0.0  0.0  0.019208
# 4      022011111010400301003       01       04  ...   0.0  0.0  0.040138
# ...                      ...      ...      ...  ...   ...  ...       ...
# 36058  022011111195200108010       19       52  ...   0.0  0.0  0.000000
# 36059  022011111195200108011       19       52  ...   0.0  0.0  0.000000
# 36060  022011111195200108012       19       52  ...   0.0  0.0  0.000000
# 36061  022011111195200108013       19       52  ...   0.0  0.0  0.000000
# 36062  022011111195200108014       19       52  ...   0.0  0.0  0.000000
#
# [36063 rows x 95 columns]

# %% [markdown]
# Seguimos cambiando nombres de columnas...

# %%
gen_xx_cols = gen_xx_cols.rename(columns = {'Total_afiliados' : 'Afiliados SS Minicipio', 'prop_autonomos' : '% Afiliados SS autónomos', 'total Dtes Empleo	' : 'Paro registrado Municipio', 'prop_hombres	' : '% Paro Hombres'})

# %%
gen_xx_cols = gen_xx_cols.rename(columns = {'prop_mayores_45' : '% Paro mayores 45', 'RNM per 2017' : 'Renta persona 2017', 'RNM per 2015' : 'Renta persona 2015', 'RNM hog 2017' : 'Renta hogar 2017' , 'RNM hog 2015' : 'Renta hogar 2015'})

# %%
gen_xx_cols = gen_xx_cols.rename(columns = {'Sal 2018' : 'Renta Salarios 2018', 'Sal 2015' : 'Renta Salarios 2015', 'Pen 2018' : 'Renta Pensiones 2018', 'Pen 2015' : 'Renta Pensiones 2015' , 'Desem 2018' : 'Renta Desempleo 2018', 'Desem 2015' : 'Renta Desempleo 2015'})

# %%
gen_xx_cols.head()
# Out:
#                  Sección cod_ccaa cod_prov cod_mun  ... % UP % Vox % Cs      % IU
# 0  022011111010400101001       01       04   04001  ...  0.0   0.0  0.0  0.038462
# 1  022011111010400201001       01       04   04002  ...  0.0   0.0  0.0  0.045249
# 2  022011111010400301001       01       04   04003  ...  0.0   0.0  0.0  0.024345
# 3  022011111010400301002       01       04   04003  ...  0.0   0.0  0.0  0.019208
# 4  022011111010400301003       01       04   04003  ...  0.0   0.0  0.0  0.040138
#
# [5 rows x 95 columns]

# %% [markdown]
# ... y seguimos.

# %%
gen_xx_cols = gen_xx_cols.rename(columns = {'total Dtes Empleo' : 'Paro Registrado Municipio', 'prop_hombres' : '% Paro Hombres', 'Desempleo' : '% Paro s/ Afiliados SS Municipio'})

# %%
gen_xx_cols.head()
# Out:
#                  Sección cod_ccaa cod_prov cod_mun  ... % UP % Vox % Cs      % IU
# 0  022011111010400101001       01       04   04001  ...  0.0   0.0  0.0  0.038462
# 1  022011111010400201001       01       04   04002  ...  0.0   0.0  0.0  0.045249
# 2  022011111010400301001       01       04   04003  ...  0.0   0.0  0.0  0.024345
# 3  022011111010400301002       01       04   04003  ...  0.0   0.0  0.0  0.019208
# 4  022011111010400301003       01       04   04003  ...  0.0   0.0  0.0  0.040138
#
# [5 rows x 95 columns]

# %%
gen_xx_cols = gen_xx_cols.rename(columns = {'mayores_65_años' : '% mayores_65_años', 'menores_19_años' : '% menores_19_años'})

# %% [markdown]
# Añadimos una columna de edades intermedias que es resta de las de menores y mayores de 65 años.

# %%
gen_xx_cols['% 20-64 años'] = 1 - gen_xx_cols['% mayores_65_años'] - gen_xx_cols['% menores_19_años']

# %%
gen_xx_cols.head()
# Out:
#                  Sección cod_ccaa cod_prov  ... % Cs      % IU % 20-64 años
# 0  022011111010400101001       01       04  ...  0.0  0.038462     0.599317
# 1  022011111010400201001       01       04  ...  0.0  0.045249     0.611765
# 2  022011111010400301001       01       04  ...  0.0  0.024345     0.638716
# 3  022011111010400301002       01       04  ...  0.0  0.019208     0.666244
# 4  022011111010400301003       01       04  ...  0.0  0.040138     0.643935
#
# [5 rows x 96 columns]

# %% [markdown]
# Añadimos otra columna, la de la proporcion de afiliados a la SS del total del municipio, que creemos que podría ser una variable importante y estar correlacionada con el voto.

# %%
gen_xx_cols['% Afiliados SS / Población'] = gen_xx_cols['Afiliados SS Minicipio'] / gen_xx_cols['Total']

# %%
gen_xx_cols = gen_xx_cols.rename(columns = {'Total' : 'Población Total', '% menores_19_años' : '% menores 19 años', '% mayores_65_años' : '% mayores 65 años', })

# %%
gen_xx_cols.head()
# Out:
#                  Sección cod_ccaa  ... % 20-64 años % Afiliados SS / Población
# 0  022011111010400101001       01  ...     0.599317                   0.191809
# 1  022011111010400201001       01  ...     0.611765                   0.284559
# 2  022011111010400301001       01  ...     0.638716                   7.413043
# 3  022011111010400301002       01  ...     0.666244                   4.535149
# 4  022011111010400301003       01  ...     0.643935                   4.002795
#
# [5 rows x 97 columns]

# %% [markdown]
# Ya no tenemos más columnas que añadir, por lo que nos ponemos a ordenarlas de forma conveniente, con las definiciones geográficas a la izquierda, seguida de los datos electorales, y finalmente los sociodemográficos.

# %%
gen_xx_cols.columns
# Out:
# Index(['Sección', 'cod_ccaa', 'cod_prov', 'cod_mun', 'CCAA', 'Provincia',
#        'Municipio', 'Censo_Esc', 'Votos_Total', 'Nulos', 'Votos_Válidos',
#        'Blanco', 'V_Cand', 'PP', 'PSOE', 'Cs', 'UP', 'IU', 'VOX', 'UPyD', 'MP',
#        'CiU', 'ERC', 'JxC', 'CUP', 'DiL', 'PNV', 'Bildu', 'Amaiur', 'CC', 'FA',
#        'TE', 'BNG', 'PRC', 'GBai', 'Compromis', 'PACMA', 'Otros', 'cod_sec',
#        '0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
#        '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79',
#        '80-84', '85-89', '90-94', '95-99', '100 y más', 'Población Total',
#        'Hombres', 'Mujeres', 'Afiliados SS Minicipio',
#        '% Afiliados SS autónomos', 'Paro Registrado Municipio',
#        '% Paro Hombres', '% Paro mayores 45', 'Renta persona 2017',
#        'Renta persona 2015', 'Renta hogar 2017', 'Renta hogar 2015',
#        'Renta Salarios 2018', 'Renta Salarios 2015', 'Renta Pensiones 2018',
#        'Renta Pensiones 2015', 'Renta Desempleo 2018', 'Renta Desempleo 2015',
#        'Participación', 'dict_res', 'dict_res_ord', 'Ganador', 'Segundo',
#        'Tercero', 'Cuarto', 'Quinto', '% mayores 65 años', '% menores 19 años',
#        '% Paro s/ Afiliados SS Municipio', '% PP', '% PSOE', '% UP', '% Vox',
#        '% Cs', '% IU', '% 20-64 años', '% Afiliados SS / Población'],
#       dtype='object')

# %%
ord_cols = ['Sección', 'cod_ccaa', 'cod_prov', 'cod_mun', 'cod_sec', 'CCAA', 'Provincia',
       'Municipio', 'Censo_Esc', 'Votos_Total','Participación', 'Nulos', 'Votos_Válidos',
       'Blanco', 'V_Cand', 'PP', 'PSOE', 'Cs', 'UP', 'IU', 'VOX', 'UPyD', 'MP',
       'CiU', 'ERC', 'JxC', 'CUP', 'DiL', 'PNV', 'Bildu', 'Amaiur', 'CC', 'FA',
       'TE', 'BNG', 'PRC', 'GBai', 'Compromis', 'PACMA', 'Otros', '% PP',
       '% PSOE', '% UP', '% Vox', '% Cs', '% IU', 'Ganador',
       'Segundo', 'Tercero', 'Cuarto', 'Quinto',
       '0-4', '5-9', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39',
       '40-44', '45-49', '50-54', '55-59', '60-64', '65-69', '70-74', '75-79',
       '80-84', '85-89', '90-94', '95-99', '100 y más', 'Población Total',
       'Hombres', 'Mujeres',  '% mayores 65 años', '% 20-64 años',
       '% menores 19 años','Afiliados SS Minicipio',
       '% Afiliados SS autónomos', '% Afiliados SS / Población', 'Paro Registrado Municipio',
       '% Paro Hombres', '% Paro mayores 45', '% Paro s/ Afiliados SS Municipio',  'Renta persona 2017',
       'Renta persona 2015', 'Renta hogar 2017', 'Renta hogar 2015',
       'Renta Salarios 2018', 'Renta Salarios 2015', 'Renta Pensiones 2018',
       'Renta Pensiones 2015', 'Renta Desempleo 2018', 'Renta Desempleo 2015',
       'dict_res', 'dict_res_ord']

# %%
len(ord_cols)
# Out:
# 97

# %%
gen_xx_cols = gen_xx_cols[ord_cols]

# %%
gen_xx_cols.head()
# Out:
#                  Sección  ...                                       dict_res_ord
# 0  022011111010400101001  ...  [('PP', 434), ('PSOE', 373), ('IU', 34), ('UPy...
# 1  022011111010400201001  ...  [('PSOE', 454), ('PP', 361), ('IU', 40), ('UPy...
# 2  022011111010400301001  ...  [('PP', 364), ('PSOE', 129), ('UPyD', 14), ('I...
# 3  022011111010400301002  ...  [('PP', 547), ('PSOE', 223), ('UPyD', 23), ('O...
# 4  022011111010400301003  ...  [('PP', 598), ('PSOE', 195), ('IU', 35), ('UPy...
#
# [5 rows x 97 columns]

# %% [markdown]
# Finalmente guardamos el dataset, que será el que utilizamos para modelar. Nos dimos cuenta al casi acabar la práctica que la columna de las CCAA están mal, ya que el INE y el Ministerio del Interior utilizan distincos códigos para ellas. Intentaremos corregirlo, a fin de cuentas se trataría de hacer un mapeo.
#
# Obviamente, hay un dataset por cada elección.

# %%
gen_xx_cols.to_csv('/content/drive/MyDrive/Proyecto_KeepCoding - Propio/Data/Gen-11-Nov/gen_N11_unif_cols_prov.txt', sep = ',', index = False)
