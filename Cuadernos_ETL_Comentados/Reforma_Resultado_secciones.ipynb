# %% [markdown]
# # Reforma (uniformización) de los resultados electorales

# %% [markdown]
# Ya vimos en el cuaderno re transformación inicial, que solo obteníamos las columans de los partidos que se presentaban en cada elección. Como creemos que conviene que el dataset de las cinco elecciones tengan las mismas columnas, eso es lo que conseguimos en este cuaderno.
#
# Aprovecharemos de paso para incluir una columna adicional.

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Cargamos el dataset que ya obtuvimos en el cuaderno anterior. Utilizaremos en este ejemplo los de las elecciones de noviembre de 2019.

# %%
res_partidos = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding (1)/Data/Gen-19-Nov/resultados_comp_N19.txt')

# %%
res_partidos
# Out:
#                      Sección  Censo_Esc  Votos_Total  Nulos  ...  PSOE  TE  UP  VOX
# 0      022019111010400101001       1002          717      7  ...   310   0  30  122
# 1      022019111010400201001       1013          711     12  ...   349   0  42  147
# 2      022019111010400301001        667          484      7  ...   128   0  34  116
# 3      022019111010400301002       1306          909      3  ...   220   0  58  312
# 4      022019111010400301003       1551          975     12  ...   202   0  52  327
# ...                      ...        ...          ...    ...  ...   ...  ..  ..  ...
# 36297  022019111195200108011       1638         1021      3  ...   140   0  28  158
# 36298  022019111195200108012       1676         1057      9  ...   205   0  35  210
# 36299  022019111195200108013       1132          638      5  ...   113   0  25  144
# 36300  022019111195200108014        899          527      4  ...    87   0  12  126
# 36301  022019111195200108015       1656          965      7  ...   199   0  23  209
#
# [36302 rows x 24 columns]

# %% [markdown]
# Listamos las columnas del dataset, que incluye, pero no solo, los partidos principales de las elecciones.

# %%
list(res_partidos)
# Out:
# ['Sección',
#  'Censo_Esc',
#  'Votos_Total',
#  'Nulos',
#  'Blanco',
#  'V_Cand',
#  'BNG',
#  'Bildu',
#  'CC',
#  'CUP',
#  'Cs',
#  'ERC',
#  'GBai',
#  'JxC',
#  'MP',
#  'Otros',
#  'PACMA',
#  'PNV',
#  'PP',
#  'PRC',
#  'PSOE',
#  'TE',
#  'UP',
#  'VOX']

# %% [markdown]
# Cargamos la lista nuestra de partidos, que será la común para las cinco elecciones.

# %%
partidos = pd.read_csv('/content/drive/MyDrive/Proyecto_KeepCoding (1)/Data/Gen-19-Nov/Partidos.txt', names=['Número', 'Sigla', 'Partido'])

# %%
partidos
# Out:
#     Número      Sigla                             Partido
# 0        1         PP                     Partido Popular
# 1        2       PSOE   Partido Socialista Obrero Español
# 2        3         Cs                         Ciudadanos
# 3        4         UP                     Unidas Podemos
# 4        5         IU                    Izquierda Unida
# 5        6        VOX                                Vox
# 6        7       UPyD        Unión Progreso y Democracia
# 7        8         MP                           Más País
# 8        9        CiU                Convergencia i Unió
# 9       10        ERC  Esquerra Republicana de Catalunya
# 10      11        JxC                Junts per Catalunya
# 11      12        CUP     Candidatures de Unitat Popular
# 12      13        DiL              Democracia i Llibertat
# 13      14        PNV         Partido Nacionalista Vasco
# 14      15      Bildu                            EH Bildu
# 15      16     Amaiur                              Amaiur
# 16      17         CC                   Coalición Canaria
# 17      18         FA                       Foro Asturias
# 18      19         TE                      Teruel Existe
# 19      20        BNG         Bloque Nacionalista Galego
# 20      21        PRC  Partido Regionalista de Cantabria
# 21      22       GBai                           Geroa Bai
# 22      23  Compromis                          Compromis
# 23      24      PACMA                               Pacma
# 24      25      Otros                              Otros

# %% [markdown]
# Almacenamos las siglas de los partidos en una lista.

# %%
lista_partidos = partidos['Sigla']

# %%
lista_partidos
# Out:
# 0            PP
# 1          PSOE
# 2            Cs
# 3            UP
# 4            IU
# 5           VOX
# 6          UPyD
# 7            MP
# 8           CiU
# 9           ERC
# 10          JxC
# 11          CUP
# 12          DiL
# 13          PNV
# 14        Bildu
# 15       Amaiur
# 16           CC
# 17           FA
# 18           TE
# 19          BNG
# 20          PRC
# 21         GBai
# 22    Compromis
# 23        PACMA
# 24        Otros
# Name: Sigla, dtype: object

# %%
lista_partidos.tolist()
# Out:
# ['PP',
#  'PSOE',
#  'Cs',
#  'UP',
#  'IU',
#  'VOX',
#  'UPyD',
#  'MP',
#  'CiU',
#  'ERC',
#  'JxC',
#  'CUP',
#  'DiL',
#  'PNV',
#  'Bildu',
#  'Amaiur',
#  'CC',
#  'FA',
#  'TE',
#  'BNG',
#  'PRC',
#  'GBai',
#  'Compromis',
#  'PACMA',
#  'Otros']

# %%
lista_partidos
# Out:
# 0            PP
# 1          PSOE
# 2            Cs
# 3            UP
# 4            IU
# 5           VOX
# 6          UPyD
# 7            MP
# 8           CiU
# 9           ERC
# 10          JxC
# 11          CUP
# 12          DiL
# 13          PNV
# 14        Bildu
# 15       Amaiur
# 16           CC
# 17           FA
# 18           TE
# 19          BNG
# 20          PRC
# 21         GBai
# 22    Compromis
# 23        PACMA
# 24        Otros
# Name: Sigla, dtype: object

# %% [markdown]
# Ahora simplemente hacemos una resta de sets a partir de las siglas de partidos de nuestra lista, y las que aparecen en el dataset de noviembre de 2019. Como cabía esperar, formaciones como IU o UPyD ya no se presentaron entonces.

# %%
part = list(set(lista_partidos.tolist()) - set(list(res_partidos)))

# %%
part
# Out:
# ['UPyD', 'CiU', 'DiL', 'FA', 'IU', 'Compromis', 'Amaiur']

# %% [markdown]
# Pero esas columnas son precisamente las que hay que añadir en este caso, aunque sean simplemente columnas llenas de ceros.

# %%
for item in part:
    res_partidos[item] = 0

# %%
res_partidos
# Out:
#                      Sección  Censo_Esc  Votos_Total  ...  IU  Compromis  Amaiur
# 0      022019111010400101001       1002          717  ...   0          0       0
# 1      022019111010400201001       1013          711  ...   0          0       0
# 2      022019111010400301001        667          484  ...   0          0       0
# 3      022019111010400301002       1306          909  ...   0          0       0
# 4      022019111010400301003       1551          975  ...   0          0       0
# ...                      ...        ...          ...  ...  ..        ...     ...
# 36297  022019111195200108011       1638         1021  ...   0          0       0
# 36298  022019111195200108012       1676         1057  ...   0          0       0
# 36299  022019111195200108013       1132          638  ...   0          0       0
# 36300  022019111195200108014        899          527  ...   0          0       0
# 36301  022019111195200108015       1656          965  ...   0          0       0
#
# [36302 rows x 31 columns]

# %%
list_partidos = lista_partidos.tolist()

# %% [markdown]
# Definimos una nueva columnas que, sinceramente, se nos olvidó definir en el cuaderno de la transformación inicial, se trata de los votos válidos.

# %%
res_partidos['Votos_Válidos'] = res_partidos['Votos_Total'] - res_partidos['Nulos']

# %%
res_partidos
# Out:
#                      Sección  Censo_Esc  ...  Amaiur  Votos_Válidos
# 0      022019111010400101001       1002  ...       0            710
# 1      022019111010400201001       1013  ...       0            699
# 2      022019111010400301001        667  ...       0            477
# 3      022019111010400301002       1306  ...       0            906
# 4      022019111010400301003       1551  ...       0            963
# ...                      ...        ...  ...     ...            ...
# 36297  022019111195200108011       1638  ...       0           1018
# 36298  022019111195200108012       1676  ...       0           1048
# 36299  022019111195200108013       1132  ...       0            633
# 36300  022019111195200108014        899  ...       0            523
# 36301  022019111195200108015       1656  ...       0            958
#
# [36302 rows x 32 columns]

# %% [markdown]
# Ahora se trata de que las columnas tengan también el mismo orden, comenzamos intecalando la de votos válidos dentro de las que no son de siglas de partidos.

# %%
list_datos_sec = list(res_partidos)[0:6]

# %%
list_datos_sec
# Out:
# ['Sección', 'Censo_Esc', 'Votos_Total', 'Nulos', 'Blanco', 'V_Cand']

# %%
list_datos_sec.insert(4, 'Votos_Válidos' )

# %%
list_datos_sec
# Out:
# ['Sección',
#  'Censo_Esc',
#  'Votos_Total',
#  'Nulos',
#  'Votos_Válidos',
#  'Blanco',
#  'V_Cand']

# %% [markdown]
# Ahora añadimos las siglas de los partidos a la lista que definirá el orden de las columnas, que llamaremos 'orden_cols'.

# %%
list_datos_sec.extend(list_partidos)

# %%
list_datos_sec
# Out:
# ['Sección',
#  'Censo_Esc',
#  'Votos_Total',
#  'Nulos',
#  'Votos_Válidos',
#  'Blanco',
#  'V_Cand',
#  'PP',
#  'PSOE',
#  'Cs',
#  'UP',
#  'IU',
#  'VOX',
#  'UPyD',
#  'MP',
#  'CiU',
#  'ERC',
#  'JxC',
#  'CUP',
#  'DiL',
#  'PNV',
#  'Bildu',
#  'Amaiur',
#  'CC',
#  'FA',
#  'TE',
#  'BNG',
#  'PRC',
#  'GBai',
#  'Compromis',
#  'PACMA',
#  'Otros']

# %%
orden_cols = list_datos_sec

# %%
orden_cols
# Out:
# ['Sección',
#  'Censo_Esc',
#  'Votos_Total',
#  'Nulos',
#  'Votos_Válidos',
#  'Blanco',
#  'V_Cand',
#  'PP',
#  'PSOE',
#  'Cs',
#  'UP',
#  'IU',
#  'VOX',
#  'UPyD',
#  'MP',
#  'CiU',
#  'ERC',
#  'JxC',
#  'CUP',
#  'DiL',
#  'PNV',
#  'Bildu',
#  'Amaiur',
#  'CC',
#  'FA',
#  'TE',
#  'BNG',
#  'PRC',
#  'GBai',
#  'Compromis',
#  'PACMA',
#  'Otros']

# %% [markdown]
# Finalmente, reformamos el dataset con el orden de columnas que queremos.

# %%
res_partidos = res_partidos[orden_cols]

# %%
res_partidos
# Out:
#                      Sección  Censo_Esc  Votos_Total  ...  Compromis  PACMA  Otros
# 0      022019111010400101001       1002          717  ...          0      3      2
# 1      022019111010400201001       1013          711  ...          0      2      2
# 2      022019111010400301001        667          484  ...          0      3      0
# 3      022019111010400301002       1306          909  ...          0      6      3
# 4      022019111010400301003       1551          975  ...          0      5      3
# ...                      ...        ...          ...  ...        ...    ...    ...
# 36297  022019111195200108011       1638         1021  ...          0      0    348
# 36298  022019111195200108012       1676         1057  ...          0      0     97
# 36299  022019111195200108013       1132          638  ...          0      0    108
# 36300  022019111195200108014        899          527  ...          0      0     85
# 36301  022019111195200108015       1656          965  ...          0      0    137
#
# [36302 rows x 32 columns]

# %% [markdown]
# Guardamos el dataset de resultados de elecciones, en este caso 'resultados_comp_N19_ref.txt', y hacemos de forma análoga con los de las otras cuatro elecciones.

# %%
res_partidos.to_csv('/content/drive/MyDrive/Proyecto_KeepCoding (1)/Data/Gen-19-Nov/resultados_comp_N19_ref.txt', sep = ',', index = False)
